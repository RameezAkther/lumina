# %% [markdown]
# ## Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ResidualBlock(nn.Module):
    """
    Novelty 1: Residual Block
    Replaces standard double conv. Helps in training deeper networks 
    and preserving feature identity.
    """
    def __init__(self, in_c, out_c):
        super().__init__()
        self.conv1 = nn.Conv2d(in_c, out_c, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(out_c)
        self.conv2 = nn.Conv2d(out_c, out_c, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(out_c)
        
        # Shortcut connection to match dimensions
        self.shortcut = nn.Sequential()
        if in_c != out_c:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_c, out_c, kernel_size=1, padding=0),
                nn.BatchNorm2d(out_c)
            )

    def forward(self, x):
        shortcut = self.shortcut(x)
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.bn2(self.conv2(x))
        x += shortcut  # The "Residual" connection
        return F.relu(x)

class AttentionGate(nn.Module):
    """
    Novelty 2: Attention Gate
    Filters the skip connection features. It uses the coarser signal 
    from the decoder (g) to highlight relevant regions in the encoder features (x).
    """
    def __init__(self, in_c, gate_c, inter_c):
        super().__init__()
        # W_g: Transform gating signal
        self.Wg = nn.Sequential(
            nn.Conv2d(gate_c, inter_c, kernel_size=1, padding=0),
            nn.BatchNorm2d(inter_c)
        )
        # W_x: Transform skip connection
        self.Wx = nn.Sequential(
            nn.Conv2d(in_c, inter_c, kernel_size=1, padding=0),
            nn.BatchNorm2d(inter_c)
        )
        # Psi: Combine and activate
        self.psi = nn.Sequential(
            nn.Conv2d(inter_c, 1, kernel_size=1, padding=0),
            nn.BatchNorm2d(1),
            nn.Sigmoid()
        )
        
    def forward(self, x, g):
        g1 = self.Wg(g)
        x1 = self.Wx(x)
        psi = F.relu(g1 + x1)
        psi = self.psi(psi)
        return x * psi  # Scale the skip connection by the attention map

class ResAttUNet(nn.Module):
    def __init__(self, in_channels=3, out_channels=1):
        super().__init__()
        
        # --- Encoder (Downsampling) ---
        self.e1 = ResidualBlock(in_channels, 64)
        self.e2 = ResidualBlock(64, 128)
        self.e3 = ResidualBlock(128, 256)
        self.e4 = ResidualBlock(256, 512)
        
        self.pool = nn.MaxPool2d(2, 2)
        
        # --- Bridge ---
        self.b = ResidualBlock(512, 1024)
        
        # --- Decoder (Upsampling + Attention) ---
        
        # Up 1
        self.up1 = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.att1 = AttentionGate(in_c=512, gate_c=1024, inter_c=256)
        self.d1 = ResidualBlock(1024 + 512, 512)
        
        # Up 2
        self.up2 = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.att2 = AttentionGate(in_c=256, gate_c=512, inter_c=128)
        self.d2 = ResidualBlock(512 + 256, 256)
        
        # [NEW] Deep Supervision Output 2 (from 256 channels)
        self.ds_out3 = nn.Conv2d(256, out_channels, kernel_size=1) 
        
        # Up 3
        self.up3 = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.att3 = AttentionGate(in_c=128, gate_c=256, inter_c=64)
        self.d3 = ResidualBlock(256 + 128, 128)

        # [NEW] Deep Supervision Output 3 (from 128 channels)
        self.ds_out2 = nn.Conv2d(128, out_channels, kernel_size=1)
        
        # Up 4
        self.up4 = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.att4 = AttentionGate(in_c=64, gate_c=128, inter_c=32)
        self.d4 = ResidualBlock(128 + 64, 64)
        
        # Output (Final)
        self.out = nn.Conv2d(64, out_channels, kernel_size=1)
        
    def forward(self, x):
        # Encoder
        x1 = self.e1(x)
        p1 = self.pool(x1)
        
        x2 = self.e2(p1)
        p2 = self.pool(x2)
        
        x3 = self.e3(p2)
        p3 = self.pool(x3)
        
        x4 = self.e4(p3)
        p4 = self.pool(x4)
        
        # Bridge
        b = self.b(p4)
        
        # Decoder
        
        # Block 1
        d1 = self.up1(b)
        x4 = self.att1(x=x4, g=d1)
        d1 = torch.cat((x4, d1), dim=1)
        d1 = self.d1(d1)
        
        # Block 2
        d2 = self.up2(d1)
        x3 = self.att2(x=x3, g=d2)
        d2 = torch.cat((x3, d2), dim=1)
        d2 = self.d2(d2)
        # [NEW] Capture Intermediate Output (1/4 resolution)
        out3 = self.ds_out3(d2)

        # Block 3
        d3 = self.up3(d2)
        x2 = self.att3(x=x2, g=d3)
        d3 = torch.cat((x2, d3), dim=1)
        d3 = self.d3(d3)
        # [NEW] Capture Intermediate Output (1/2 resolution)
        out2 = self.ds_out2(d3)
        
        # Block 4
        d4 = self.up4(d3)
        x1 = self.att4(x=x1, g=d4)
        d4 = torch.cat((x1, d4), dim=1)
        d4 = self.d4(d4)
        
        # Final Output
        out_final = self.out(d4)
        
        # [NEW] Return List: [Final, Middle, Coarse]
        # We must upsample the smaller maps to match the input size for Loss calculation
        return [
            out_final,
            F.interpolate(out2, scale_factor=2, mode='bilinear', align_corners=True),
            F.interpolate(out3, scale_factor=4, mode='bilinear', align_corners=True)
        ]

# %% [markdown]
# ## Loss

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class DiceBCELoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(DiceBCELoss, self).__init__()

    def forward(self, inputs, targets, smooth=1):
        # inputs are LOGITS (raw output from model, no sigmoid yet)
        
        # --- 1. BCE Loss (Must use logits for stability in AMP) ---
        # binary_cross_entropy_with_logits includes the sigmoid internally
        bce_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduction='mean')
        
        # --- 2. Dice Loss (Needs probabilities 0-1) ---
        # We manually apply sigmoid just for the Dice calculation
        inputs_prob = torch.sigmoid(inputs)
        
        # Flatten for Dice math
        inputs_flat = inputs_prob.view(-1)
        targets_flat = targets.view(-1)
        
        intersection = (inputs_flat * targets_flat).sum()                            
        dice_loss = 1 - (2.*intersection + smooth)/(inputs_flat.sum() + targets_flat.sum() + smooth)  
        
        return bce_loss + dice_loss

# %% [markdown]
# ## Training Code

# %%
import os
import cv2
import csv
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import albumentations as A 
from albumentations.pytorch import ToTensorV2
from tqdm import tqdm 

# --- IMPORT YOUR MODEL & LOSS ---
# Ensure model.py and loss.py are in the same directory
# from model import ResAttUNet 
# from loss import DiceBCELoss 

# --- CONFIGURATION ---
LEARNING_RATE = 1e-4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATCH_SIZE = 4 
NUM_EPOCHS = 100
NUM_WORKERS = 2
IMAGE_HEIGHT = 256 
IMAGE_WIDTH = 256
PIN_MEMORY = True
TRAIN_IMG_DIR = "/kaggle/input/ghandinagar-rooftop-segmentation-dataset/train"
TEST_IMG_DIR = "/kaggle/input/ghandinagar-rooftop-segmentation-dataset/test"
CSV_FILE = "training_log.csv" # File to store metrics

# --- 1. THE DATASET CLASS ---
class SolarDataset(Dataset):
    def __init__(self, image_dir, transform=None):
        self.image_dir = image_dir
        self.transform = transform
        self.images = [img for img in os.listdir(image_dir) if img.endswith(".jpg")]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, index):
        img_path = os.path.join(self.image_dir, self.images[index])
        
        # Construct mask path (Adjust suffix if needed for your dataset)
        mask_path = img_path.replace(".jpg", "_mask.png")

        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        
        if mask is None:
            raise FileNotFoundError(f"Mask not found: {mask_path}")

        mask[mask == 255] = 1.0 
        
        if self.transform is not None:
            augmentations = self.transform(image=image, mask=mask)
            image = augmentations["image"]
            mask = augmentations["mask"]

        return image, mask

# --- 2. DST STITCHER FUNCTION ---
def make_mosaic(images, masks):
    """Stitches 4 images into 1 (DST Stitcher)."""
    batch_size = images.shape[0]
    if batch_size < 4: 
        return images, masks 

    stitched_imgs = []
    stitched_masks = []

    for i in range(0, batch_size - 3, 4):
        # Resize to half size
        img1 = F.interpolate(images[i].unsqueeze(0), scale_factor=0.5)
        img2 = F.interpolate(images[i+1].unsqueeze(0), scale_factor=0.5)
        img3 = F.interpolate(images[i+2].unsqueeze(0), scale_factor=0.5)
        img4 = F.interpolate(images[i+3].unsqueeze(0), scale_factor=0.5)

        mask1 = F.interpolate(masks[i].unsqueeze(0).unsqueeze(0), scale_factor=0.5)
        mask2 = F.interpolate(masks[i+1].unsqueeze(0).unsqueeze(0), scale_factor=0.5)
        mask3 = F.interpolate(masks[i+2].unsqueeze(0).unsqueeze(0), scale_factor=0.5)
        mask4 = F.interpolate(masks[i+3].unsqueeze(0).unsqueeze(0), scale_factor=0.5)

        # Stitch
        top = torch.cat([img1, img2], dim=3)    
        bot = torch.cat([img3, img4], dim=3)
        final_img = torch.cat([top, bot], dim=2) 

        top_m = torch.cat([mask1, mask2], dim=3)
        bot_m = torch.cat([mask3, mask4], dim=3)
        final_mask = torch.cat([top_m, bot_m], dim=2).squeeze(1)

        stitched_imgs.append(final_img)
        stitched_masks.append(final_mask)

    if len(stitched_imgs) == 0:
        return images, masks

    return torch.cat(stitched_imgs, dim=0), torch.cat(stitched_masks, dim=0)

# --- 3. TRAINING UTILS ---
def get_loaders(train_dir, val_dir, batch_size, train_transform, val_transform, num_workers=4, pin_memory=True):
    train_ds = SolarDataset(image_dir=train_dir, transform=train_transform)
    train_loader = DataLoader(
        train_ds, batch_size=batch_size, num_workers=num_workers, pin_memory=pin_memory, shuffle=True,
    )
    val_ds = SolarDataset(image_dir=val_dir, transform=val_transform)
    val_loader = DataLoader(
        val_ds, batch_size=batch_size, num_workers=num_workers, pin_memory=pin_memory, shuffle=False,
    )
    return train_loader, val_loader

def evaluate(loader, model, loss_fn, device="cuda"):
    """Calculates comprehensive metrics."""
    model.eval()
    
    val_loss = 0
    num_correct = 0
    num_pixels = 0
    dice_score = 0
    iou_score = 0
    precision = 0
    recall = 0
    
    loop = tqdm(loader, desc="Validating", leave=False)

    with torch.no_grad():
        for x, y in loop:
            x = x.to(device)
            # FIX: Added .float() here
            y = y.float().to(device).unsqueeze(1) 
            
            # Forward pass
            outputs = model(x)
            final_pred = outputs[0] # Take Final Output
            
            # Calculate Validation Loss
            loss = loss_fn(final_pred, y)
            val_loss += loss.item()
            
            # Binarize Predictions
            preds = torch.sigmoid(final_pred)
            preds = (preds > 0.5).float() 
            
            # Calculate TP, FP, FN
            TP = (preds * y).sum()
            FP = (preds * (1 - y)).sum()
            FN = ((1 - preds) * y).sum()
            
            # Metrics Calculation
            num_correct += (preds == y).sum().item()
            num_pixels += torch.numel(preds)
            
            # Smoothing to avoid division by zero
            smooth = 1e-8
            dice_score += (2 * TP) / (2 * TP + FP + FN + smooth)
            iou_score += TP / (TP + FP + FN + smooth)
            precision += TP / (TP + FP + smooth)
            recall += TP / (TP + FN + smooth)

    # Average metrics over batches
    length = len(loader)
    metrics = {
        "val_loss": val_loss / length,
        "accuracy": (num_correct / num_pixels) * 100,
        "dice": (dice_score / length).item(),
        "iou": (iou_score / length).item(),
        "precision": (precision / length).item(),
        "recall": (recall / length).item()
    }
    
    model.train()
    return metrics

# --- 4. MAIN TRAINING LOOP ---
def train_fn(loader, model, optimizer, loss_fn, scaler):
    loop = tqdm(loader, desc="Training")
    USE_MOSAIC = False 
    running_loss = 0.0

    for batch_idx, (data, targets) in enumerate(loop):
        data = data.to(DEVICE)
        targets = targets.float().to(DEVICE) 

        # DST Trigger
        if USE_MOSAIC:
            data, targets = make_mosaic(data, targets)
            USE_MOSAIC = False 

        with torch.amp.autocast('cuda'): 
            # Forward
            outputs = model(data) 
            final_pred, mid_pred, coarse_pred = outputs[0], outputs[1], outputs[2]
            
            targets_unsqueezed = targets.unsqueeze(1)
            
            # Deep Supervision Loss
            loss_1 = loss_fn(final_pred, targets_unsqueezed)
            loss_2 = loss_fn(mid_pred, targets_unsqueezed)
            loss_3 = loss_fn(coarse_pred, targets_unsqueezed)
            
            total_loss = loss_1 + (0.5 * loss_2) + (0.4 * loss_3)
            
            # DST Random Trigger
            if torch.rand(1).item() < 0.2: 
                USE_MOSAIC = True

        optimizer.zero_grad()
        scaler.scale(total_loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += total_loss.item()
        loop.set_postfix(loss=total_loss.item())
        
    return running_loss / len(loader)

def main():
    # --- TRANSFORMS ---
    train_transform = A.Compose([
        A.Resize(height=IMAGE_HEIGHT, width=IMAGE_WIDTH),
        A.Rotate(limit=35, p=1.0),
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.1),
        A.Normalize(mean=[0.0, 0.0, 0.0], std=[1.0, 1.0, 1.0], max_pixel_value=255.0),
        ToTensorV2(),
    ])

    val_transform = A.Compose([
        A.Resize(height=IMAGE_HEIGHT, width=IMAGE_WIDTH),
        A.Normalize(mean=[0.0, 0.0, 0.0], std=[1.0, 1.0, 1.0], max_pixel_value=255.0),
        ToTensorV2(),
    ])

    # --- INITIALIZE ---
    model = ResAttUNet(in_channels=3, out_channels=1).to(DEVICE)
    loss_fn = DiceBCELoss() 
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
    scaler = torch.amp.GradScaler('cuda')

    train_loader, val_loader = get_loaders(
        TRAIN_IMG_DIR, TEST_IMG_DIR, BATCH_SIZE, train_transform, val_transform, NUM_WORKERS, PIN_MEMORY
    )

    # --- CSV SETUP ---
    header = ['epoch', 'train_loss', 'val_loss', 'accuracy', 'dice', 'iou', 'precision', 'recall']
    with open(CSV_FILE, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(header)

    best_dice_score = 0.0

    print(f"Starting training on {DEVICE}...")

    # --- EPOCH LOOP ---
    for epoch in range(NUM_EPOCHS):
        print(f"\nEpoch {epoch+1}/{NUM_EPOCHS}")
        
        # 1. Train
        avg_train_loss = train_fn(train_loader, model, optimizer, loss_fn, scaler)
        
        # 2. Evaluate
        metrics = evaluate(val_loader, model, loss_fn, DEVICE)
        
        # 3. Print Metrics
        print(f"Train Loss: {avg_train_loss:.4f} | Val Loss: {metrics['val_loss']:.4f}")
        print(f"Dice: {metrics['dice']:.4f} | IoU: {metrics['iou']:.4f} | Acc: {metrics['accuracy']:.2f}%")
        print(f"Precision: {metrics['precision']:.4f} | Recall: {metrics['recall']:.4f}")
        
        # 4. Save Best Model Only
        if metrics['dice'] > best_dice_score:
            best_dice_score = metrics['dice']
            checkpoint = {
                "state_dict": model.state_dict(),
                "optimizer": optimizer.state_dict(),
                "epoch": epoch,
                "best_dice": best_dice_score,
            }
            torch.save(checkpoint, "best_checkpoint.pth.tar")
            print(f"--> New best model saved! (Dice: {best_dice_score:.4f})")
            
        # 5. Log to CSV
        with open(CSV_FILE, 'a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow([
                epoch + 1, 
                avg_train_loss, 
                metrics['val_loss'], 
                metrics['accuracy'], 
                metrics['dice'], 
                metrics['iou'], 
                metrics['precision'], 
                metrics['recall']
            ])

if __name__ == "__main__":
    main()
# Out:
# Starting training on cuda...
#
# Epoch 1/100
# Training: 100%|██████████| 129/129 [00:27<00:00,  4.77it/s, loss=0.932]
# Train Loss: 1.2132 | Val Loss: 0.6365
# Dice: 0.8002 | IoU: 0.6673 | Acc: 91.35%
# Precision: 0.6875 | Recall: 0.9578
# --> New best model saved! (Dice: 0.8002)
#
# Epoch 2/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.24it/s, loss=0.707]
# Train Loss: 0.8497 | Val Loss: 0.6252
# Dice: 0.7904 | IoU: 0.6539 | Acc: 90.65%
# Precision: 0.6652 | Recall: 0.9750
#
# Epoch 3/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.24it/s, loss=0.633]
# Train Loss: 0.7365 | Val Loss: 0.4347
# Dice: 0.8589 | IoU: 0.7531 | Acc: 94.41%
# Precision: 0.7883 | Recall: 0.9440
# --> New best model saved! (Dice: 0.8589)
#
# Epoch 4/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.25it/s, loss=0.539]
# Train Loss: 0.6612 | Val Loss: 0.3631
# Dice: 0.8680 | IoU: 0.7673 | Acc: 95.06%
# Precision: 0.8382 | Recall: 0.9007
# --> New best model saved! (Dice: 0.8680)
#
# Epoch 5/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.30it/s, loss=0.484]
# Train Loss: 0.6148 | Val Loss: 0.3526
# Dice: 0.8650 | IoU: 0.7626 | Acc: 94.83%
# Precision: 0.8182 | Recall: 0.9182
#
# Epoch 6/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.30it/s, loss=0.594]
# Train Loss: 0.5881 | Val Loss: 0.3458
# Dice: 0.8663 | IoU: 0.7647 | Acc: 94.76%
# Precision: 0.8009 | Recall: 0.9442
#
# Epoch 7/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.30it/s, loss=0.557]
# Train Loss: 0.5590 | Val Loss: 0.3471
# Dice: 0.8662 | IoU: 0.7646 | Acc: 94.71%
# Precision: 0.7951 | Recall: 0.9520
#
# Epoch 8/100
# Training: 100%|██████████| 129/129 [00:25<00:00,  5.06it/s, loss=0.464]
# Train Loss: 0.5307 | Val Loss: 0.3024
# Dice: 0.8751 | IoU: 0.7783 | Acc: 95.22%
# Precision: 0.8275 | Recall: 0.9290
# --> New best model saved! (Dice: 0.8751)
#
# Epoch 9/100
# Training: 100%|██████████| 129/129 [00:25<00:00,  5.14it/s, loss=0.554]
# Train Loss: 0.5242 | Val Loss: 0.2892
# Dice: 0.8794 | IoU: 0.7852 | Acc: 95.48%
# Precision: 0.8472 | Recall: 0.9148
# --> New best model saved! (Dice: 0.8794)
#
# Epoch 10/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.17it/s, loss=0.523]
# Train Loss: 0.5117 | Val Loss: 0.3000
# Dice: 0.8732 | IoU: 0.7755 | Acc: 95.08%
# Precision: 0.8141 | Recall: 0.9421
#
# Epoch 11/100
# Training: 100%|██████████| 129/129 [00:25<00:00,  5.14it/s, loss=0.474]
# Train Loss: 0.5039 | Val Loss: 0.2854
# Dice: 0.8767 | IoU: 0.7809 | Acc: 95.41%
# Precision: 0.8505 | Recall: 0.9052
#
# Epoch 12/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.22it/s, loss=0.562]
# Train Loss: 0.4976 | Val Loss: 0.2716
# Dice: 0.8827 | IoU: 0.7905 | Acc: 95.52%
# Precision: 0.8347 | Recall: 0.9372
# --> New best model saved! (Dice: 0.8827)
#
# Epoch 13/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.27it/s, loss=0.455]
# Train Loss: 0.4926 | Val Loss: 0.2910
# Dice: 0.8774 | IoU: 0.7821 | Acc: 95.20%
# Precision: 0.8133 | Recall: 0.9532
#
# Epoch 14/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.22it/s, loss=0.467]
# Train Loss: 0.4978 | Val Loss: 0.2676
# Dice: 0.8832 | IoU: 0.7914 | Acc: 95.59%
# Precision: 0.8431 | Recall: 0.9279
# --> New best model saved! (Dice: 0.8832)
#
# Epoch 15/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.22it/s, loss=0.435]
# Train Loss: 0.4825 | Val Loss: 0.2649
# Dice: 0.8831 | IoU: 0.7912 | Acc: 95.50%
# Precision: 0.8302 | Recall: 0.9439
#
# Epoch 16/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.33it/s, loss=0.471]
# Train Loss: 0.4836 | Val Loss: 0.2583
# Dice: 0.8844 | IoU: 0.7934 | Acc: 95.59%
# Precision: 0.8376 | Recall: 0.9375
# --> New best model saved! (Dice: 0.8844)
#
# Epoch 17/100
# Training: 100%|██████████| 129/129 [00:25<00:00,  5.11it/s, loss=0.578]
# Train Loss: 0.4677 | Val Loss: 0.2618
# Dice: 0.8836 | IoU: 0.7920 | Acc: 95.57%
# Precision: 0.8393 | Recall: 0.9335
#
# Epoch 18/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.28it/s, loss=0.5]
# Train Loss: 0.4758 | Val Loss: 0.2632
# Dice: 0.8833 | IoU: 0.7915 | Acc: 95.54%
# Precision: 0.8351 | Recall: 0.9380
#
# Epoch 19/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.28it/s, loss=0.564]
# Train Loss: 0.4699 | Val Loss: 0.2604
# Dice: 0.8840 | IoU: 0.7926 | Acc: 95.62%
# Precision: 0.8471 | Recall: 0.9250
#
# Epoch 20/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.33it/s, loss=0.381]
# Train Loss: 0.4714 | Val Loss: 0.2609
# Dice: 0.8854 | IoU: 0.7947 | Acc: 95.66%
# Precision: 0.8446 | Recall: 0.9310
# --> New best model saved! (Dice: 0.8854)
#
# Epoch 21/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.25it/s, loss=0.47]
# Train Loss: 0.4627 | Val Loss: 0.2665
# Dice: 0.8773 | IoU: 0.7817 | Acc: 95.58%
# Precision: 0.8803 | Recall: 0.8749
#
# Epoch 22/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.22it/s, loss=0.433]
# Train Loss: 0.4615 | Val Loss: 0.2534
# Dice: 0.8864 | IoU: 0.7964 | Acc: 95.69%
# Precision: 0.8432 | Recall: 0.9349
# --> New best model saved! (Dice: 0.8864)
#
# Epoch 23/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.36it/s, loss=0.409]
# Train Loss: 0.4641 | Val Loss: 0.2519
# Dice: 0.8874 | IoU: 0.7980 | Acc: 95.80%
# Precision: 0.8590 | Recall: 0.9183
# --> New best model saved! (Dice: 0.8874)
#
# Epoch 24/100
# Training: 100%|██████████| 129/129 [00:25<00:00,  5.09it/s, loss=0.485]
# Train Loss: 0.4533 | Val Loss: 0.2460
# Dice: 0.8879 | IoU: 0.7989 | Acc: 95.81%
# Precision: 0.8574 | Recall: 0.9212
# --> New best model saved! (Dice: 0.8879)
#
# Epoch 25/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.30it/s, loss=0.385]
# Train Loss: 0.4535 | Val Loss: 0.2500
# Dice: 0.8861 | IoU: 0.7961 | Acc: 95.71%
# Precision: 0.8499 | Recall: 0.9262
#
# Epoch 26/100
# Training: 100%|██████████| 129/129 [00:25<00:00,  5.14it/s, loss=0.376]
# Train Loss: 0.4476 | Val Loss: 0.2541
# Dice: 0.8847 | IoU: 0.7936 | Acc: 95.58%
# Precision: 0.8339 | Recall: 0.9428
#
# Epoch 27/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.25it/s, loss=0.435]
# Train Loss: 0.4522 | Val Loss: 0.2514
# Dice: 0.8843 | IoU: 0.7930 | Acc: 95.81%
# Precision: 0.8802 | Recall: 0.8889
#
# Epoch 28/100
# Training: 100%|██████████| 129/129 [00:25<00:00,  5.11it/s, loss=0.459]
# Train Loss: 0.4453 | Val Loss: 0.2525
# Dice: 0.8857 | IoU: 0.7953 | Acc: 95.70%
# Precision: 0.8510 | Recall: 0.9240
#
# Epoch 29/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.27it/s, loss=0.528]
# Train Loss: 0.4512 | Val Loss: 0.2491
# Dice: 0.8871 | IoU: 0.7976 | Acc: 95.82%
# Precision: 0.8641 | Recall: 0.9119
#
# Epoch 30/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.22it/s, loss=0.573]
# Train Loss: 0.4486 | Val Loss: 0.2422
# Dice: 0.8901 | IoU: 0.8025 | Acc: 95.93%
# Precision: 0.8669 | Recall: 0.9153
# --> New best model saved! (Dice: 0.8901)
#
# Epoch 31/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.17it/s, loss=0.387]
# Train Loss: 0.4391 | Val Loss: 0.2484
# Dice: 0.8869 | IoU: 0.7973 | Acc: 95.83%
# Precision: 0.8674 | Recall: 0.9081
#
# Epoch 32/100
# Training: 100%|██████████| 129/129 [00:25<00:00,  5.11it/s, loss=0.365]
# Train Loss: 0.4399 | Val Loss: 0.2440
# Dice: 0.8882 | IoU: 0.7994 | Acc: 95.90%
# Precision: 0.8729 | Recall: 0.9047
#
# Epoch 33/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.36it/s, loss=0.37]
# Train Loss: 0.4473 | Val Loss: 0.2432
# Dice: 0.8900 | IoU: 0.8023 | Acc: 95.91%
# Precision: 0.8647 | Recall: 0.9175
#
# Epoch 34/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.22it/s, loss=0.415]
# Train Loss: 0.4406 | Val Loss: 0.2443
# Dice: 0.8884 | IoU: 0.7997 | Acc: 95.78%
# Precision: 0.8477 | Recall: 0.9339
#
# Epoch 35/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.28it/s, loss=0.587]
# Train Loss: 0.4423 | Val Loss: 0.2399
# Dice: 0.8889 | IoU: 0.8005 | Acc: 95.79%
# Precision: 0.8482 | Recall: 0.9346
#
# Epoch 36/100
# Training: 100%|██████████| 129/129 [00:22<00:00,  5.64it/s, loss=0.339]
# Train Loss: 0.4524 | Val Loss: 0.2424
# Dice: 0.8885 | IoU: 0.7999 | Acc: 95.88%
# Precision: 0.8673 | Recall: 0.9114
#
# Epoch 37/100
# Training: 100%|██████████| 129/129 [00:23<00:00,  5.38it/s, loss=0.369]
# Train Loss: 0.4419 | Val Loss: 0.2403
# Dice: 0.8907 | IoU: 0.8035 | Acc: 95.93%
# Precision: 0.8626 | Recall: 0.9215
# --> New best model saved! (Dice: 0.8907)
#
# Epoch 38/100
# Training: 100%|██████████| 129/129 [00:25<00:00,  5.09it/s, loss=0.389]
# Train Loss: 0.4287 | Val Loss: 0.2387
# Dice: 0.8904 | IoU: 0.8029 | Acc: 95.88%
# Precision: 0.8541 | Recall: 0.9306
#
# Epoch 39/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.17it/s, loss=0.455]
# Train Loss: 0.4365 | Val Loss: 0.2387
# Dice: 0.8908 | IoU: 0.8036 | Acc: 95.95%
# Precision: 0.8679 | Recall: 0.9158
# --> New best model saved! (Dice: 0.8908)
#
# Epoch 40/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.27it/s, loss=0.462]
# Train Loss: 0.4336 | Val Loss: 0.2377
# Dice: 0.8904 | IoU: 0.8029 | Acc: 95.92%
# Precision: 0.8636 | Recall: 0.9195
#
# Epoch 41/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.27it/s, loss=0.451]
# Train Loss: 0.4351 | Val Loss: 0.2501
# Dice: 0.8844 | IoU: 0.7932 | Acc: 95.81%
# Precision: 0.8816 | Recall: 0.8878
#
# Epoch 42/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.36it/s, loss=0.43]
# Train Loss: 0.4354 | Val Loss: 0.2335
# Dice: 0.8916 | IoU: 0.8048 | Acc: 95.98%
# Precision: 0.8681 | Recall: 0.9171
# --> New best model saved! (Dice: 0.8916)
#
# Epoch 43/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.25it/s, loss=0.48]
# Train Loss: 0.4317 | Val Loss: 0.2537
# Dice: 0.8825 | IoU: 0.7902 | Acc: 95.77%
# Precision: 0.8865 | Recall: 0.8792
#
# Epoch 44/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.22it/s, loss=0.499]
# Train Loss: 0.4307 | Val Loss: 0.2397
# Dice: 0.8909 | IoU: 0.8039 | Acc: 95.90%
# Precision: 0.8558 | Recall: 0.9298
#
# Epoch 45/100
# Training: 100%|██████████| 129/129 [00:23<00:00,  5.54it/s, loss=0.489]
# Train Loss: 0.4445 | Val Loss: 0.2384
# Dice: 0.8897 | IoU: 0.8018 | Acc: 95.83%
# Precision: 0.8501 | Recall: 0.9339
#
# Epoch 46/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.33it/s, loss=0.387]
# Train Loss: 0.4356 | Val Loss: 0.2435
# Dice: 0.8888 | IoU: 0.8004 | Acc: 95.91%
# Precision: 0.8720 | Recall: 0.9070
#
# Epoch 47/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.16it/s, loss=0.402]
# Train Loss: 0.4304 | Val Loss: 0.2384
# Dice: 0.8904 | IoU: 0.8030 | Acc: 95.93%
# Precision: 0.8651 | Recall: 0.9180
#
# Epoch 48/100
# Training: 100%|██████████| 129/129 [00:23<00:00,  5.48it/s, loss=0.402]
# Train Loss: 0.4381 | Val Loss: 0.2354
# Dice: 0.8921 | IoU: 0.8057 | Acc: 95.99%
# Precision: 0.8661 | Recall: 0.9203
# --> New best model saved! (Dice: 0.8921)
#
# Epoch 49/100
# Training: 100%|██████████| 129/129 [00:22<00:00,  5.66it/s, loss=0.507]
# Train Loss: 0.4392 | Val Loss: 0.2426
# Dice: 0.8871 | IoU: 0.7976 | Acc: 95.88%
# Precision: 0.8781 | Recall: 0.8970
#
# Epoch 50/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.28it/s, loss=0.535]
# Train Loss: 0.4265 | Val Loss: 0.2359
# Dice: 0.8895 | IoU: 0.8014 | Acc: 95.95%
# Precision: 0.8748 | Recall: 0.9052
#
# Epoch 51/100
# Training: 100%|██████████| 129/129 [00:23<00:00,  5.42it/s, loss=0.403]
# Train Loss: 0.4327 | Val Loss: 0.2419
# Dice: 0.8905 | IoU: 0.8031 | Acc: 95.93%
# Precision: 0.8650 | Recall: 0.9183
#
# Epoch 52/100
# Training: 100%|██████████| 129/129 [00:23<00:00,  5.39it/s, loss=0.462]
# Train Loss: 0.4296 | Val Loss: 0.2412
# Dice: 0.8886 | IoU: 0.8000 | Acc: 95.83%
# Precision: 0.8580 | Recall: 0.9221
#
# Epoch 53/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.36it/s, loss=0.503]
# Train Loss: 0.4289 | Val Loss: 0.2381
# Dice: 0.8913 | IoU: 0.8043 | Acc: 95.98%
# Precision: 0.8685 | Recall: 0.9159
#
# Epoch 54/100
# Training: 100%|██████████| 129/129 [00:25<00:00,  5.14it/s, loss=0.403]
# Train Loss: 0.4171 | Val Loss: 0.2400
# Dice: 0.8910 | IoU: 0.8039 | Acc: 95.98%
# Precision: 0.8708 | Recall: 0.9127
#
# Epoch 55/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.16it/s, loss=0.478]
# Train Loss: 0.4203 | Val Loss: 0.2397
# Dice: 0.8900 | IoU: 0.8023 | Acc: 95.92%
# Precision: 0.8654 | Recall: 0.9168
#
# Epoch 56/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.30it/s, loss=0.382]
# Train Loss: 0.4224 | Val Loss: 0.2341
# Dice: 0.8924 | IoU: 0.8062 | Acc: 95.99%
# Precision: 0.8647 | Recall: 0.9226
# --> New best model saved! (Dice: 0.8924)
#
# Epoch 57/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.27it/s, loss=0.494]
# Train Loss: 0.4218 | Val Loss: 0.2364
# Dice: 0.8909 | IoU: 0.8038 | Acc: 95.99%
# Precision: 0.8750 | Recall: 0.9082
#
# Epoch 58/100
# Training: 100%|██████████| 129/129 [00:26<00:00,  4.96it/s, loss=0.389]
# Train Loss: 0.4107 | Val Loss: 0.2360
# Dice: 0.8912 | IoU: 0.8043 | Acc: 96.02%
# Precision: 0.8780 | Recall: 0.9055
#
# Epoch 59/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.25it/s, loss=0.509]
# Train Loss: 0.4221 | Val Loss: 0.2354
# Dice: 0.8913 | IoU: 0.8044 | Acc: 95.99%
# Precision: 0.8715 | Recall: 0.9128
#
# Epoch 60/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.30it/s, loss=0.369]
# Train Loss: 0.4213 | Val Loss: 0.2372
# Dice: 0.8912 | IoU: 0.8043 | Acc: 95.95%
# Precision: 0.8638 | Recall: 0.9212
#
# Epoch 61/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.22it/s, loss=0.322]
# Train Loss: 0.4180 | Val Loss: 0.2410
# Dice: 0.8909 | IoU: 0.8038 | Acc: 95.91%
# Precision: 0.8570 | Recall: 0.9284
#
# Epoch 62/100
# Training: 100%|██████████| 129/129 [00:25<00:00,  5.00it/s, loss=0.604]
# Train Loss: 0.4144 | Val Loss: 0.2430
# Dice: 0.8881 | IoU: 0.7992 | Acc: 95.85%
# Precision: 0.8664 | Recall: 0.9119
#
# Epoch 63/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.18it/s, loss=0.398]
# Train Loss: 0.4211 | Val Loss: 0.2390
# Dice: 0.8907 | IoU: 0.8033 | Acc: 96.00%
# Precision: 0.8776 | Recall: 0.9048
#
# Epoch 64/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.25it/s, loss=0.513]
# Train Loss: 0.4190 | Val Loss: 0.2375
# Dice: 0.8910 | IoU: 0.8039 | Acc: 96.00%
# Precision: 0.8755 | Recall: 0.9078
#
# Epoch 65/100
# Training: 100%|██████████| 129/129 [00:25<00:00,  5.14it/s, loss=0.363]
# Train Loss: 0.4145 | Val Loss: 0.2351
# Dice: 0.8918 | IoU: 0.8052 | Acc: 95.92%
# Precision: 0.8549 | Recall: 0.9327
#
# Epoch 66/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.36it/s, loss=0.384]
# Train Loss: 0.4214 | Val Loss: 0.2359
# Dice: 0.8917 | IoU: 0.8051 | Acc: 95.98%
# Precision: 0.8682 | Recall: 0.9173
#
# Epoch 67/100
# Training: 100%|██████████| 129/129 [00:23<00:00,  5.48it/s, loss=0.531]
# Train Loss: 0.4261 | Val Loss: 0.2403
# Dice: 0.8912 | IoU: 0.8043 | Acc: 95.95%
# Precision: 0.8630 | Recall: 0.9220
#
# Epoch 68/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.17it/s, loss=0.373]
# Train Loss: 0.4128 | Val Loss: 0.2365
# Dice: 0.8918 | IoU: 0.8052 | Acc: 95.99%
# Precision: 0.8687 | Recall: 0.9169
#
# Epoch 69/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.31it/s, loss=0.391]
# Train Loss: 0.4196 | Val Loss: 0.2321
# Dice: 0.8930 | IoU: 0.8071 | Acc: 96.01%
# Precision: 0.8651 | Recall: 0.9234
# --> New best model saved! (Dice: 0.8930)
#
# Epoch 70/100
# Training: 100%|██████████| 129/129 [00:23<00:00,  5.42it/s, loss=0.462]
# Train Loss: 0.4203 | Val Loss: 0.2385
# Dice: 0.8900 | IoU: 0.8023 | Acc: 95.93%
# Precision: 0.8680 | Recall: 0.9139
#
# Epoch 71/100
# Training: 100%|██████████| 129/129 [00:23<00:00,  5.39it/s, loss=0.388]
# Train Loss: 0.4194 | Val Loss: 0.2374
# Dice: 0.8910 | IoU: 0.8039 | Acc: 95.92%
# Precision: 0.8585 | Recall: 0.9267
#
# Epoch 72/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.30it/s, loss=0.49]
# Train Loss: 0.4184 | Val Loss: 0.2406
# Dice: 0.8884 | IoU: 0.7996 | Acc: 95.91%
# Precision: 0.8759 | Recall: 0.9019
#
# Epoch 73/100
# Training: 100%|██████████| 129/129 [00:23<00:00,  5.42it/s, loss=0.398]
# Train Loss: 0.4200 | Val Loss: 0.2388
# Dice: 0.8905 | IoU: 0.8032 | Acc: 95.94%
# Precision: 0.8654 | Recall: 0.9179
#
# Epoch 74/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.20it/s, loss=0.579]
# Train Loss: 0.4127 | Val Loss: 0.2386
# Dice: 0.8905 | IoU: 0.8032 | Acc: 95.96%
# Precision: 0.8705 | Recall: 0.9122
#
# Epoch 75/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.17it/s, loss=0.458]
# Train Loss: 0.4110 | Val Loss: 0.2352
# Dice: 0.8917 | IoU: 0.8050 | Acc: 95.96%
# Precision: 0.8629 | Recall: 0.9232
#
# Epoch 76/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.27it/s, loss=0.39]
# Train Loss: 0.4135 | Val Loss: 0.2370
# Dice: 0.8910 | IoU: 0.8039 | Acc: 95.98%
# Precision: 0.8723 | Recall: 0.9112
#
# Epoch 77/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.22it/s, loss=0.49]
# Train Loss: 0.4114 | Val Loss: 0.2422
# Dice: 0.8895 | IoU: 0.8016 | Acc: 95.83%
# Precision: 0.8511 | Recall: 0.9324
#
# Epoch 78/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.28it/s, loss=0.443]
# Train Loss: 0.4161 | Val Loss: 0.2355
# Dice: 0.8919 | IoU: 0.8054 | Acc: 96.00%
# Precision: 0.8699 | Recall: 0.9157
#
# Epoch 79/100
# Training: 100%|██████████| 129/129 [00:23<00:00,  5.42it/s, loss=0.38]
# Train Loss: 0.4192 | Val Loss: 0.2350
# Dice: 0.8927 | IoU: 0.8068 | Acc: 96.06%
# Precision: 0.8756 | Recall: 0.9112
#
# Epoch 80/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.33it/s, loss=0.333]
# Train Loss: 0.4138 | Val Loss: 0.2421
# Dice: 0.8923 | IoU: 0.8060 | Acc: 95.97%
# Precision: 0.8591 | Recall: 0.9288
#
# Epoch 81/100
# Training: 100%|██████████| 129/129 [00:25<00:00,  5.08it/s, loss=0.451]
# Train Loss: 0.4052 | Val Loss: 0.2351
# Dice: 0.8906 | IoU: 0.8033 | Acc: 95.99%
# Precision: 0.8749 | Recall: 0.9076
#
# Epoch 82/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.25it/s, loss=0.526]
# Train Loss: 0.4102 | Val Loss: 0.2338
# Dice: 0.8916 | IoU: 0.8050 | Acc: 96.00%
# Precision: 0.8692 | Recall: 0.9158
#
# Epoch 83/100
# Training: 100%|██████████| 129/129 [00:25<00:00,  5.09it/s, loss=0.524]
# Train Loss: 0.4051 | Val Loss: 0.2337
# Dice: 0.8921 | IoU: 0.8056 | Acc: 96.03%
# Precision: 0.8744 | Recall: 0.9111
#
# Epoch 84/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.25it/s, loss=0.566]
# Train Loss: 0.4098 | Val Loss: 0.2605
# Dice: 0.8802 | IoU: 0.7868 | Acc: 95.61%
# Precision: 0.8655 | Recall: 0.8966
#
# Epoch 85/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.37it/s, loss=0.41]
# Train Loss: 0.4146 | Val Loss: 0.2390
# Dice: 0.8923 | IoU: 0.8061 | Acc: 96.00%
# Precision: 0.8664 | Recall: 0.9205
#
# Epoch 86/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.34it/s, loss=0.388]
# Train Loss: 0.4078 | Val Loss: 0.2339
# Dice: 0.8921 | IoU: 0.8058 | Acc: 95.96%
# Precision: 0.8586 | Recall: 0.9289
#
# Epoch 87/100
# Training: 100%|██████████| 129/129 [00:23<00:00,  5.39it/s, loss=0.369]
# Train Loss: 0.4164 | Val Loss: 0.2367
# Dice: 0.8910 | IoU: 0.8040 | Acc: 95.99%
# Precision: 0.8729 | Recall: 0.9108
#
# Epoch 88/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.19it/s, loss=0.434]
# Train Loss: 0.4058 | Val Loss: 0.2420
# Dice: 0.8912 | IoU: 0.8044 | Acc: 95.96%
# Precision: 0.8660 | Recall: 0.9186
#
# Epoch 89/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.25it/s, loss=0.446]
# Train Loss: 0.4080 | Val Loss: 0.2439
# Dice: 0.8900 | IoU: 0.8022 | Acc: 95.92%
# Precision: 0.8675 | Recall: 0.9144
#
# Epoch 90/100
# Training: 100%|██████████| 129/129 [00:25<00:00,  5.14it/s, loss=0.37]
# Train Loss: 0.4060 | Val Loss: 0.2374
# Dice: 0.8916 | IoU: 0.8048 | Acc: 95.95%
# Precision: 0.8610 | Recall: 0.9250
#
# Epoch 91/100
# Training: 100%|██████████| 129/129 [00:25<00:00,  5.11it/s, loss=0.406]
# Train Loss: 0.4034 | Val Loss: 0.2384
# Dice: 0.8913 | IoU: 0.8043 | Acc: 95.98%
# Precision: 0.8688 | Recall: 0.9156
#
# Epoch 92/100
# Training: 100%|██████████| 129/129 [00:23<00:00,  5.45it/s, loss=0.353]
# Train Loss: 0.4133 | Val Loss: 0.2352
# Dice: 0.8917 | IoU: 0.8052 | Acc: 95.99%
# Precision: 0.8679 | Recall: 0.9176
#
# Epoch 93/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.19it/s, loss=0.492]
# Train Loss: 0.4041 | Val Loss: 0.2321
# Dice: 0.8925 | IoU: 0.8065 | Acc: 96.05%
# Precision: 0.8739 | Recall: 0.9126
#
# Epoch 94/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.20it/s, loss=0.321]
# Train Loss: 0.4062 | Val Loss: 0.2380
# Dice: 0.8923 | IoU: 0.8061 | Acc: 96.00%
# Precision: 0.8647 | Recall: 0.9223
#
# Epoch 95/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.20it/s, loss=0.388]
# Train Loss: 0.4043 | Val Loss: 0.2412
# Dice: 0.8900 | IoU: 0.8022 | Acc: 95.90%
# Precision: 0.8616 | Recall: 0.9209
#
# Epoch 96/100
# Training: 100%|██████████| 129/129 [00:23<00:00,  5.45it/s, loss=0.299]
# Train Loss: 0.4075 | Val Loss: 0.2388
# Dice: 0.8911 | IoU: 0.8040 | Acc: 96.00%
# Precision: 0.8742 | Recall: 0.9093
#
# Epoch 97/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.36it/s, loss=0.483]
# Train Loss: 0.4067 | Val Loss: 0.2400
# Dice: 0.8906 | IoU: 0.8033 | Acc: 95.99%
# Precision: 0.8761 | Recall: 0.9063
#
# Epoch 98/100
# Training: 100%|██████████| 129/129 [00:24<00:00,  5.36it/s, loss=0.329]
# Train Loss: 0.4082 | Val Loss: 0.2370
# Dice: 0.8925 | IoU: 0.8064 | Acc: 95.99%
# Precision: 0.8625 | Recall: 0.9253
#
# Epoch 99/100
# Training: 100%|██████████| 129/129 [00:23<00:00,  5.42it/s, loss=0.365]
# Train Loss: 0.4123 | Val Loss: 0.2466
# Dice: 0.8855 | IoU: 0.7949 | Acc: 95.85%
# Precision: 0.8834 | Recall: 0.8883
#
# Epoch 100/100
# Training: 100%|██████████| 129/129 [00:23<00:00,  5.54it/s, loss=0.432]
# Train Loss: 0.4110 | Val Loss: 0.2357
# Dice: 0.8922 | IoU: 0.8059 | Acc: 96.03%
# Precision: 0.8725 | Recall: 0.9135

# %% [markdown]
# ## Metric Plots

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# --- CONFIGURATION ---
CSV_FILE = "/kaggle/working/training_log.csv"
OUTPUT_IMAGE = "metrics_plot.png"

def plot_training_metrics(csv_file, output_file):
    # 1. Load Data
    try:
        df = pd.read_csv(csv_file)
    except FileNotFoundError:
        print(f"Error: Could not find {csv_file}. Make sure you have run the training script first.")
        return

    # 2. Set "Aesthetic" Style (Seaborn)
    sns.set_theme(style="whitegrid", context="paper", font_scale=1.2)
    
    # Create a figure with a 2x3 grid
    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
    fig.suptitle('Training & Validation Metrics', fontsize=20, fontweight='bold', y=0.98)

    # --- PLOT 1: LOSS (Train vs Val) ---
    sns.lineplot(ax=axes[0, 0], data=df, x='epoch', y='train_loss', label='Train Loss', 
                 linewidth=2.5, color='#E74C3C', marker='o')
    sns.lineplot(ax=axes[0, 0], data=df, x='epoch', y='val_loss', label='Val Loss', 
                 linewidth=2.5, color='#2E86C1', marker='o')
    axes[0, 0].set_title('Loss Curves', fontweight='bold')
    axes[0, 0].set_ylabel('Loss')
    axes[0, 0].legend()

    # --- PLOT 2: DICE & IoU (The most important segmentation metrics) ---
    sns.lineplot(ax=axes[0, 1], data=df, x='epoch', y='dice', label='Dice Score', 
                 linewidth=2.5, color='#27AE60', marker='s')
    sns.lineplot(ax=axes[0, 1], data=df, x='epoch', y='iou', label='IoU Score', 
                 linewidth=2.5, color='#F39C12', marker='s')
    axes[0, 1].set_title('Segmentation Performance (Dice & IoU)', fontweight='bold')
    axes[0, 1].set_ylabel('Score (0-1)')
    axes[0, 1].legend()

    # --- PLOT 3: ACCURACY ---
    sns.lineplot(ax=axes[0, 2], data=df, x='epoch', y='accuracy', 
                 linewidth=2.5, color='#8E44AD', marker='D')
    axes[0, 2].set_title('Pixel Accuracy (%)', fontweight='bold')
    axes[0, 2].set_ylabel('Accuracy (%)')

    # --- PLOT 4: PRECISION vs RECALL ---
    sns.lineplot(ax=axes[1, 0], data=df, x='epoch', y='precision', label='Precision', 
                 linewidth=2.5, color='#16A085', marker='^')
    sns.lineplot(ax=axes[1, 0], data=df, x='epoch', y='recall', label='Recall', 
                 linewidth=2.5, color='#C0392B', marker='v')
    axes[1, 0].set_title('Precision vs Recall', fontweight='bold')
    axes[1, 0].set_ylabel('Score (0-1)')
    axes[1, 0].legend()

    # --- PLOT 5: DICE vs LOSS (Correlation check) ---
    # Helps see if Loss going down actually improves Dice
    ax2 = axes[1, 1].twinx()
    sns.lineplot(ax=axes[1, 1], data=df, x='epoch', y='val_loss', color='#2E86C1', 
                 label='Val Loss', legend=False, linestyle='--')
    sns.lineplot(ax=ax2, data=df, x='epoch', y='dice', color='#27AE60', 
                 label='Dice', legend=False, linewidth=2.5)
    
    axes[1, 1].set_title('Correlation: Val Loss (Blue) vs Dice (Green)', fontweight='bold')
    axes[1, 1].set_ylabel('Val Loss')
    ax2.set_ylabel('Dice Score')
    
    # --- PLOT 6: DATA TABLE (Summary) ---
    axes[1, 2].axis('off')
    # Create a concise table of the best epoch
    best_epoch_idx = df['dice'].idxmax()
    best_row = df.iloc[best_epoch_idx]
    
    table_text = [
        ["Metric", "Best Value"],
        ["Best Epoch", int(best_row['epoch'])],
        ["Dice Score", f"{best_row['dice']:.4f}"],
        ["IoU Score", f"{best_row['iou']:.4f}"],
        ["Precision", f"{best_row['precision']:.4f}"],
        ["Recall", f"{best_row['recall']:.4f}"],
        ["Val Loss", f"{best_row['val_loss']:.4f}"],
    ]
    
    table = axes[1, 2].table(cellText=table_text, loc='center', cellLoc='center', 
                             colWidths=[0.4, 0.4])
    table.auto_set_font_size(False)
    table.set_fontsize(12)
    table.scale(1, 2) # Make rows taller
    axes[1, 2].set_title(f"Best Model Summary (Epoch {int(best_row['epoch'])})", fontweight='bold')

    # Final Layout Adjustments
    plt.tight_layout()
    plt.subplots_adjust(top=0.92) # Make space for main title
    
    # Save
    plt.savefig(output_file, dpi=300, bbox_inches='tight')
    print(f"✅ Plots saved successfully to {output_file}")
    plt.show()

if __name__ == "__main__":
    plot_training_metrics(CSV_FILE, OUTPUT_IMAGE)
# Out:
# ✅ Plots saved successfully to metrics_plot.png

# %% [markdown]
# ## Inference

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F  # Added missing import
import numpy as np
import cv2
import matplotlib.pyplot as plt
import albumentations as A
from albumentations.pytorch import ToTensorV2

# --- 2. CONFIGURATION ---
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
CHECKPOINT_PATH = "/kaggle/working/best_checkpoint.pth.tar"
# Replace with a valid image path from your dataset
IMAGE_PATH = "/kaggle/input/ghandinagar-rooftop-segmentation-dataset/train/sample_0_jpg.rf.4e644d9a9813cce20ae1206c171d2154.jpg" 
INPUT_SIZE = 256 

# --- 3. INFERENCE UTILS ---
def load_model(checkpoint_path):
    print(f"Loading model from {checkpoint_path}...")
    model = ResAttUNet(in_channels=3, out_channels=1).to(DEVICE)
    checkpoint = torch.load(checkpoint_path, map_location=DEVICE)
    model.load_state_dict(checkpoint["state_dict"])
    model.eval()
    return model

def predict_single_image(model, image_path):
    # 1. Read Image
    original_img = cv2.imread(image_path)
    if original_img is None:
        raise ValueError(f"Image not found at {image_path}")
    
    original_rgb = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)
    
    # 2. Preprocess
    transform = A.Compose([
        A.Resize(height=INPUT_SIZE, width=INPUT_SIZE),
        A.Normalize(mean=[0.0, 0.0, 0.0], std=[1.0, 1.0, 1.0], max_pixel_value=255.0),
        ToTensorV2(),
    ])
    
    augmented = transform(image=original_rgb)
    img_tensor = augmented["image"].unsqueeze(0).to(DEVICE)
    
    # 3. Inference
    with torch.no_grad():
        outputs = model(img_tensor) # This returns a list: [final, mid, coarse]
        
        # --- FIX IS HERE: Take index 0 ---
        logits = outputs[0] 
        
        probs = torch.sigmoid(logits)
        mask = (probs > 0.5).float()
    
    # 4. Post-processing
    mask_np = mask.squeeze().cpu().numpy()
    original_h, original_w = original_rgb.shape[:2]
    mask_resized = cv2.resize(mask_np, (original_w, original_h), interpolation=cv2.INTER_NEAREST)
    
    return original_rgb, mask_resized

def visualize_result(image, mask):
    mask_colored = np.zeros_like(image)
    mask_colored[:, :, 0] = 255 # Red
    mask_indices = mask > 0
    overlay = image.copy()
    overlay[mask_indices] = cv2.addWeighted(image[mask_indices], 0.5, mask_colored[mask_indices], 0.5, 0)

    fig, ax = plt.subplots(1, 3, figsize=(15, 5))
    ax[0].imshow(image); ax[0].set_title("Original Satellite Image"); ax[0].axis("off")
    ax[1].imshow(mask, cmap="gray"); ax[1].set_title("Predicted Segmentation Mask"); ax[1].axis("off")
    ax[2].imshow(overlay); ax[2].set_title("Overlay (Red = Rooftop)"); ax[2].axis("off")
    plt.tight_layout()
    plt.show()

# --- MAIN EXECUTION ---
if __name__ == "__main__":
    model = load_model(CHECKPOINT_PATH)
    try:
        img, pred_mask = predict_single_image(model, IMAGE_PATH)
        visualize_result(img, pred_mask)
        print("Inference Complete!")
    except Exception as e:
        print(f"Error: {e}")
# Out:
# Loading model from /kaggle/working/best_checkpoint.pth.tar...
# Inference Complete!
