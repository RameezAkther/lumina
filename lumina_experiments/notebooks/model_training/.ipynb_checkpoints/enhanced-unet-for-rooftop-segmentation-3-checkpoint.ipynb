# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ResidualBlock(nn.Module):
    """
    Novelty 1: Residual Block
    Replaces standard double conv. Helps in training deeper networks 
    and preserving feature identity.
    """
    def __init__(self, in_c, out_c):
        super().__init__()
        self.conv1 = nn.Conv2d(in_c, out_c, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(out_c)
        self.conv2 = nn.Conv2d(out_c, out_c, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(out_c)
        
        # Shortcut connection to match dimensions
        self.shortcut = nn.Sequential()
        if in_c != out_c:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_c, out_c, kernel_size=1, padding=0),
                nn.BatchNorm2d(out_c)
            )

    def forward(self, x):
        shortcut = self.shortcut(x)
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.bn2(self.conv2(x))
        x += shortcut  # The "Residual" connection
        return F.relu(x)

class AttentionGate(nn.Module):
    """
    Novelty 2: Attention Gate
    Filters the skip connection features. It uses the coarser signal 
    from the decoder (g) to highlight relevant regions in the encoder features (x).
    """
    def __init__(self, in_c, gate_c, inter_c):
        super().__init__()
        # W_g: Transform gating signal
        self.Wg = nn.Sequential(
            nn.Conv2d(gate_c, inter_c, kernel_size=1, padding=0),
            nn.BatchNorm2d(inter_c)
        )
        # W_x: Transform skip connection
        self.Wx = nn.Sequential(
            nn.Conv2d(in_c, inter_c, kernel_size=1, padding=0),
            nn.BatchNorm2d(inter_c)
        )
        # Psi: Combine and activate
        self.psi = nn.Sequential(
            nn.Conv2d(inter_c, 1, kernel_size=1, padding=0),
            nn.BatchNorm2d(1),
            nn.Sigmoid()
        )
        
    def forward(self, x, g):
        g1 = self.Wg(g)
        x1 = self.Wx(x)
        psi = F.relu(g1 + x1)
        psi = self.psi(psi)
        return x * psi  # Scale the skip connection by the attention map

class ResAttUNet(nn.Module):
    def __init__(self, in_channels=3, out_channels=1):
        super().__init__()
        
        # --- Encoder (Downsampling) ---
        self.e1 = ResidualBlock(in_channels, 64)
        self.e2 = ResidualBlock(64, 128)
        self.e3 = ResidualBlock(128, 256)
        self.e4 = ResidualBlock(256, 512)
        
        self.pool = nn.MaxPool2d(2, 2)
        
        # --- Bridge ---
        self.b = ResidualBlock(512, 1024)
        
        # --- Decoder (Upsampling + Attention) ---
        
        # Up 1
        self.up1 = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.att1 = AttentionGate(in_c=512, gate_c=1024, inter_c=256)
        self.d1 = ResidualBlock(1024 + 512, 512)
        
        # Up 2
        self.up2 = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.att2 = AttentionGate(in_c=256, gate_c=512, inter_c=128)
        self.d2 = ResidualBlock(512 + 256, 256)
        
        # [NEW] Deep Supervision Output 2 (from 256 channels)
        self.ds_out3 = nn.Conv2d(256, out_channels, kernel_size=1) 
        
        # Up 3
        self.up3 = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.att3 = AttentionGate(in_c=128, gate_c=256, inter_c=64)
        self.d3 = ResidualBlock(256 + 128, 128)

        # [NEW] Deep Supervision Output 3 (from 128 channels)
        self.ds_out2 = nn.Conv2d(128, out_channels, kernel_size=1)
        
        # Up 4
        self.up4 = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.att4 = AttentionGate(in_c=64, gate_c=128, inter_c=32)
        self.d4 = ResidualBlock(128 + 64, 64)
        
        # Output (Final)
        self.out = nn.Conv2d(64, out_channels, kernel_size=1)
        
    def forward(self, x):
        # Encoder
        x1 = self.e1(x)
        p1 = self.pool(x1)
        
        x2 = self.e2(p1)
        p2 = self.pool(x2)
        
        x3 = self.e3(p2)
        p3 = self.pool(x3)
        
        x4 = self.e4(p3)
        p4 = self.pool(x4)
        
        # Bridge
        b = self.b(p4)
        
        # Decoder
        
        # Block 1
        d1 = self.up1(b)
        x4 = self.att1(x=x4, g=d1)
        d1 = torch.cat((x4, d1), dim=1)
        d1 = self.d1(d1)
        
        # Block 2
        d2 = self.up2(d1)
        x3 = self.att2(x=x3, g=d2)
        d2 = torch.cat((x3, d2), dim=1)
        d2 = self.d2(d2)
        # [NEW] Capture Intermediate Output (1/4 resolution)
        out3 = self.ds_out3(d2)

        # Block 3
        d3 = self.up3(d2)
        x2 = self.att3(x=x2, g=d3)
        d3 = torch.cat((x2, d3), dim=1)
        d3 = self.d3(d3)
        # [NEW] Capture Intermediate Output (1/2 resolution)
        out2 = self.ds_out2(d3)
        
        # Block 4
        d4 = self.up4(d3)
        x1 = self.att4(x=x1, g=d4)
        d4 = torch.cat((x1, d4), dim=1)
        d4 = self.d4(d4)
        
        # Final Output
        out_final = self.out(d4)
        
        # [NEW] Return List: [Final, Middle, Coarse]
        # We must upsample the smaller maps to match the input size for Loss calculation
        return [
            out_final,
            F.interpolate(out2, scale_factor=2, mode='bilinear', align_corners=True),
            F.interpolate(out3, scale_factor=4, mode='bilinear', align_corners=True)
        ]

# %%
# loss.py
import torch
import torch.nn as nn
import torch.nn.functional as F

class DiceBCELoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(DiceBCELoss, self).__init__()

    def forward(self, inputs, targets, smooth=1):
        # 0. Numerical Stability: Force inputs to float32
        inputs = inputs.float()
        targets = targets.float()
        
        # 1. BCE Loss with Logits (Handles numerical stability internally)
        bce_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduction='mean')
        
        # 2. Dice Loss
        inputs_prob = torch.sigmoid(inputs)
        
        # Flatten
        inputs_flat = inputs_prob.view(-1)
        targets_flat = targets.view(-1)
        
        intersection = (inputs_flat * targets_flat).sum()                            
        dice_loss = 1 - (2.*intersection + smooth)/(inputs_flat.sum() + targets_flat.sum() + smooth)  
        
        return bce_loss + dice_loss

# %%
import os
import cv2
import csv
import shutil
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from pathlib import Path
from torch.utils.data import Dataset, DataLoader
import albumentations as A 
from albumentations.pytorch import ToTensorV2
from tqdm import tqdm 

# --- IMPORT YOUR MODEL & LOSS ---
# from model import ResAttUNet 
# from loss import DiceBCELoss 

# ==========================================
# 1. DATA PREPARATION (YOLO CONVERSION)
# ==========================================
def prepare_whu_data():
    """
    Runs the user's script to convert WHU TIF/JSON -> YOLO JPG/TXT.
    Only runs if the output directory doesn't exist yet.
    """
    INPUT_DIR = Path("/kaggle/input/whu-building-rooftop-dataset")
    WORKING_DIR = Path("/kaggle/working/datasets")
    
    if WORKING_DIR.exists():
        print("Data already prepared at", WORKING_DIR)
        return

    print("Preparing Data: Converting TIF/JSON to YOLO format...")
    # Install ultralytics for the converter if needed
    os.system("pip install ultralytics -q")
    from ultralytics.data.converter import convert_coco

    # Process Train and Validation Splits
    for split in ['train', 'val']:
        img_dir = WORKING_DIR / split / 'images'
        lbl_dir = WORKING_DIR / split / 'labels'
        img_dir.mkdir(parents=True, exist_ok=True)
        lbl_dir.mkdir(parents=True, exist_ok=True)
        
        # 1. Convert JSON to YOLO labels
        # Ultralytics creates 'coco_converted' dir
        print(f"Converting annotations for {split}...")
        try:
            convert_coco(labels_dir=str(INPUT_DIR / "annotation"), use_segments=True)
            
            # Move labels
            possible_folders = [split, 'validation'] if split == 'val' else [split]
            found_labels = False
            for folder in possible_folders:
                src_path = Path(f"coco_converted/labels/{folder}")
                if src_path.exists():
                    found_labels = True
                    for txt in src_path.glob("*.txt"):
                        shutil.move(str(txt), lbl_dir / txt.name)
            
            if not found_labels:
                print(f"Warning: No labels found for {split} in coco_converted")
        except Exception as e:
            print(f"Error converting labels: {e}")

        # 2. Convert TIF to JPG
        img_src = INPUT_DIR / split
        tif_files = list(img_src.glob("*.TIF")) + list(img_src.glob("*.tif"))
        
        print(f"Converting {len(tif_files)} images for {split}...")
        for tif_path in tqdm(tif_files):
            img = cv2.imread(str(tif_path))
            if img is not None:
                save_path = img_dir / f"{tif_path.stem}.jpg"
                cv2.imwrite(str(save_path), img, [int(cv2.IMWRITE_JPEG_QUALITY), 100])

    # Clean up
    if os.path.exists("coco_converted"):
        shutil.rmtree("coco_converted")
    print("Data Preparation Complete!")

# Run setup immediately
prepare_whu_data()

# ==========================================
# 2. CONFIGURATION (UPDATED PATHS)
# ==========================================
LEARNING_RATE = 1e-4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATCH_SIZE = 4 
NUM_EPOCHS = 75 # Adjusted for WHU (it's larger/complex)
NUM_WORKERS = 2
IMAGE_HEIGHT = 512 # WHU images are 512x512, let's keep native resolution
IMAGE_WIDTH = 512
PIN_MEMORY = True

# Point to the folders created by prepare_whu_data()
TRAIN_IMG_DIR = "/kaggle/working/datasets/train/images"
TRAIN_LABEL_DIR = "/kaggle/working/datasets/train/labels"

VAL_IMG_DIR = "/kaggle/working/datasets/val/images"
VAL_LABEL_DIR = "/kaggle/working/datasets/val/labels"

CSV_FILE = "training_log.csv" 

# ==========================================
# 3. DATASET CLASS (YOLO -> BINARY MASK)
# ==========================================
class WhuYoloDataset(Dataset):
    def __init__(self, img_dir, label_dir, transform=None):
        self.img_dir = img_dir
        self.label_dir = label_dir
        self.transform = transform
        # List only jpgs that exist
        self.images = [f for f in os.listdir(img_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, index):
        img_filename = self.images[index]
        img_path = os.path.join(self.img_dir, img_filename)
        
        # Construct label path (same filename, change extension to .txt)
        label_filename = os.path.splitext(img_filename)[0] + ".txt"
        label_path = os.path.join(self.label_dir, label_filename)

        # 1. Load Image
        image = cv2.imread(img_path)
        if image is None:
            # Fallback for corrupt images
            image = np.zeros((IMAGE_HEIGHT, IMAGE_WIDTH, 3), dtype=np.uint8)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        h, w, _ = image.shape

        # 2. Create Mask from YOLO Polygon Text
        mask = np.zeros((h, w), dtype=np.float32)

        if os.path.exists(label_path):
            with open(label_path, "r") as f:
                lines = f.readlines()
                
            for line in lines:
                parts = list(map(float, line.strip().split()))
                # YOLO format: class_id x1 y1 x2 y2 ... (normalized)
                if len(parts) > 1:
                    coords = parts[1:] # Skip class_id
                    
                    # Un-normalize coordinates
                    poly_points = []
                    for i in range(0, len(coords), 2):
                        px = int(coords[i] * w)
                        py = int(coords[i+1] * h)
                        poly_points.append([px, py])
                    
                    if len(poly_points) > 2:
                        pts = np.array(poly_points, np.int32)
                        pts = pts.reshape((-1, 1, 2))
                        # Fill polygon with 1.0 (Foreground)
                        cv2.fillPoly(mask, [pts], 1.0)
        
        # 3. Augmentations
        if self.transform is not None:
            augmentations = self.transform(image=image, mask=mask)
            image = augmentations["image"]
            mask = augmentations["mask"]

        return image, mask

# ==========================================
# 4. DST STITCHER (NO CHANGES NEEDED)
# ==========================================
def make_mosaic(images, masks):
    batch_size = images.shape[0]
    if batch_size < 4: return images, masks 

    stitched_imgs = []
    stitched_masks = []

    for i in range(0, batch_size - 3, 4):
        img1 = F.interpolate(images[i].unsqueeze(0), scale_factor=0.5)
        img2 = F.interpolate(images[i+1].unsqueeze(0), scale_factor=0.5)
        img3 = F.interpolate(images[i+2].unsqueeze(0), scale_factor=0.5)
        img4 = F.interpolate(images[i+3].unsqueeze(0), scale_factor=0.5)

        mask1 = F.interpolate(masks[i].unsqueeze(0).unsqueeze(0), scale_factor=0.5)
        mask2 = F.interpolate(masks[i+1].unsqueeze(0).unsqueeze(0), scale_factor=0.5)
        mask3 = F.interpolate(masks[i+2].unsqueeze(0).unsqueeze(0), scale_factor=0.5)
        mask4 = F.interpolate(masks[i+3].unsqueeze(0).unsqueeze(0), scale_factor=0.5)

        top = torch.cat([img1, img2], dim=3)    
        bot = torch.cat([img3, img4], dim=3)
        final_img = torch.cat([top, bot], dim=2) 

        top_m = torch.cat([mask1, mask2], dim=3)
        bot_m = torch.cat([mask3, mask4], dim=3)
        final_mask = torch.cat([top_m, bot_m], dim=2).squeeze(1)

        stitched_imgs.append(final_img)
        stitched_masks.append(final_mask)

    if len(stitched_imgs) == 0: return images, masks
    return torch.cat(stitched_imgs, dim=0), torch.cat(stitched_masks, dim=0)

# ==========================================
# 5. TRAINING UTILS (UPDATED FOR NEW DATASET)
# ==========================================
def get_loaders(train_img_dir, train_label_dir, val_img_dir, val_label_dir, 
                batch_size, train_transform, val_transform, num_workers=4, pin_memory=True):
    
    # Use WhuYoloDataset
    train_ds = WhuYoloDataset(
        img_dir=train_img_dir, 
        label_dir=train_label_dir, 
        transform=train_transform
    )
    
    train_loader = DataLoader(
        train_ds, 
        batch_size=batch_size, 
        num_workers=num_workers, 
        pin_memory=pin_memory, 
        shuffle=True,
    )

    val_ds = WhuYoloDataset(
        img_dir=val_img_dir, 
        label_dir=val_label_dir, 
        transform=val_transform
    )
    
    val_loader = DataLoader(
        val_ds, 
        batch_size=batch_size, 
        num_workers=num_workers, 
        pin_memory=pin_memory, 
        shuffle=False,
    )

    return train_loader, val_loader

def evaluate(loader, model, loss_fn, device="cuda"):
    model.eval()
    val_loss = 0
    dice_score = 0
    iou_score = 0
    precision = 0
    recall = 0
    num_correct = 0
    num_pixels = 0
    
    loop = tqdm(loader, desc="Validating", leave=False)

    with torch.no_grad():
        for x, y in loop:
            x = x.to(device)
            y = y.float().to(device).unsqueeze(1) 
            
            outputs = model(x)
            final_pred = outputs[0]
            
            loss = loss_fn(final_pred, y)
            val_loss += loss.item()
            
            preds = torch.sigmoid(final_pred)
            preds = (preds > 0.5).float() 
            
            TP = (preds * y).sum()
            FP = (preds * (1 - y)).sum()
            FN = ((1 - preds) * y).sum()
            
            smooth = 1e-8
            dice_score += (2 * TP) / (2 * TP + FP + FN + smooth)
            iou_score += TP / (TP + FP + FN + smooth)
            precision += TP / (TP + FP + smooth)
            recall += TP / (TP + FN + smooth)
            
            num_correct += (preds == y).sum().item()
            num_pixels += torch.numel(preds)

    length = len(loader)
    return {
        "val_loss": val_loss / length,
        "accuracy": (num_correct / num_pixels) * 100,
        "dice": (dice_score / length).item(),
        "iou": (iou_score / length).item(),
        "precision": (precision / length).item(),
        "recall": (recall / length).item()
    }

def train_fn(loader, model, optimizer, loss_fn): # Removed scaler argument
    loop = tqdm(loader, desc="Training")
    USE_MOSAIC = False 
    running_loss = 0.0
    valid_batches = 0 

    for batch_idx, (data, targets) in enumerate(loop):
        data = data.to(DEVICE)
        targets = targets.float().to(DEVICE) 

        # DST Trigger
        if USE_MOSAIC:
            data, targets = make_mosaic(data, targets)
            USE_MOSAIC = False 

        # --- FIX 1: REMOVE AUTOCAST (Use Full Precision) ---
        # with torch.amp.autocast('cuda'):  <-- REMOVED
        outputs = model(data) 
        final_pred, mid_pred, coarse_pred = outputs[0], outputs[1], outputs[2]
        
        targets_unsqueezed = targets.unsqueeze(1)
        
        loss_1 = loss_fn(final_pred, targets_unsqueezed)
        loss_2 = loss_fn(mid_pred, targets_unsqueezed)
        loss_3 = loss_fn(coarse_pred, targets_unsqueezed)
        
        total_loss = loss_1 + (0.5 * loss_2) + (0.4 * loss_3)
        
        if torch.rand(1).item() < 0.2: 
            USE_MOSAIC = True

        # --- SAFETY CHECK ---
        if torch.isnan(total_loss) or torch.isinf(total_loss):
            print(f"\n[Warning] Infinite/NaN loss at batch {batch_idx}. Skipping.")
            optimizer.zero_grad()
            continue 

        # --- FIX 2: STANDARD BACKPROP ---
        optimizer.zero_grad()
        total_loss.backward() # No scaler.scale()
        
        # Clip gradients to prevent explosion
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        optimizer.step() # No scaler.step()

        running_loss += total_loss.item()
        valid_batches += 1
        loop.set_postfix(loss=total_loss.item())
        
    return running_loss / max(valid_batches, 1)

# ==========================================
# 6. MAIN EXECUTION
# ==========================================
def main():
    # --- TRANSFORMS (UPDATED SIZE) ---
    train_transform = A.Compose([
        A.Resize(height=IMAGE_HEIGHT, width=IMAGE_WIDTH),
        A.Rotate(limit=35, p=1.0),
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.1),
        A.Normalize(mean=[0.0, 0.0, 0.0], std=[1.0, 1.0, 1.0], max_pixel_value=255.0),
        ToTensorV2(),
    ])

    val_transform = A.Compose([
        A.Resize(height=IMAGE_HEIGHT, width=IMAGE_WIDTH),
        A.Normalize(mean=[0.0, 0.0, 0.0], std=[1.0, 1.0, 1.0], max_pixel_value=255.0),
        ToTensorV2(),
    ])

    # --- INITIALIZE ---
    model = ResAttUNet(in_channels=3, out_channels=1).to(DEVICE)
    loss_fn = DiceBCELoss() 
    optimizer = optim.Adam(model.parameters(), lr=1e-4) # Learning rate is fine
    # scaler = torch.amp.GradScaler('cuda') <-- REMOVE THIS

    train_loader, val_loader = get_loaders(
        TRAIN_IMG_DIR, TRAIN_LABEL_DIR,
        VAL_IMG_DIR, VAL_LABEL_DIR,
        BATCH_SIZE, train_transform, val_transform, NUM_WORKERS, PIN_MEMORY
    )

    # --- CSV SETUP ---
    header = ['epoch', 'train_loss', 'val_loss', 'accuracy', 'dice', 'iou', 'precision', 'recall']
    with open(CSV_FILE, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(header)

    best_dice_score = 0.0

    print(f"Starting training on {DEVICE} (Full Precision Mode)...")

    for epoch in range(NUM_EPOCHS):
        current_epoch_idx = epoch + 1
        print(f"\nEpoch {current_epoch_idx}/{NUM_EPOCHS}")
        
        # Pass updated arguments (no scaler)
        avg_train_loss = train_fn(train_loader, model, optimizer, loss_fn) 
        metrics = evaluate(val_loader, model, loss_fn, DEVICE)
        
        print(f"Train Loss: {avg_train_loss:.4f} | Val Loss: {metrics['val_loss']:.4f}")
        print(f"Dice: {metrics['dice']:.4f} | IoU: {metrics['iou']:.4f} | Acc: {metrics['accuracy']:.2f}%")
        
        if metrics['dice'] > best_dice_score:
            best_dice_score = metrics['dice']
            checkpoint = {
                "state_dict": model.state_dict(),
                "optimizer": optimizer.state_dict(),
                "epoch": epoch,
                "best_dice": best_dice_score,
            }
            torch.save(checkpoint, "best_checkpoint.pth.tar")
            print(f"--> New best model saved! (Dice: {best_dice_score:.4f})")
            
        with open(CSV_FILE, 'a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow([
                epoch + 1, avg_train_loss, metrics['val_loss'], metrics['accuracy'], 
                metrics['dice'], metrics['iou'], metrics['precision'], metrics['recall']
            ])

if __name__ == "__main__":
    main()
# Out:
# Preparing Data: Converting TIF/JSON to YOLO format...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 26.8 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Converting annotations for train...
# Annotations /kaggle/input/whu-building-rooftop-dataset/annotation/test.json: 100% ━━━━━━━━━━━━ 1685/1685 929.6it/s 1.8s
# Annotations /kaggle/input/whu-building-rooftop-dataset/annotation/train.json: 100% ━━━━━━━━━━━━ 2604/2604 707.1it/s 3.7s
# Annotations /kaggle/input/whu-building-rooftop-dataset/annotation/validation.json: 100% ━━━━━━━━━━━━ 490/490 1.2Kit/s 0.4s
# COCO data converted successfully.
# Results saved to /kaggle/working/coco_converted
# Converting 2943 images for train...
# 100%|██████████| 2943/2943 [02:35<00:00, 18.96it/s]
# Converting annotations for val...
# Annotations /kaggle/input/whu-building-rooftop-dataset/annotation/test.json: 100% ━━━━━━━━━━━━ 1685/1685 910.9it/s 1.8s
# Annotations /kaggle/input/whu-building-rooftop-dataset/annotation/train.json: 100% ━━━━━━━━━━━━ 2604/2604 695.1it/s 3.7s
# Annotations /kaggle/input/whu-building-rooftop-dataset/annotation/validation.json: 100% ━━━━━━━━━━━━ 490/490 1.2Kit/s 0.4s
# COCO data converted successfully.
# Results saved to /kaggle/working/coco_converted2
# Converting 627 images for val...
# 100%|██████████| 627/627 [00:32<00:00, 19.49it/s]
# Data Preparation Complete!
# Starting training on cuda (Full Precision Mode)...
#
# Epoch 1/75
# Training: 100%|██████████| 736/736 [07:01<00:00,  1.75it/s, loss=0.941]
# Train Loss: 0.8517 | Val Loss: 0.6517
# Dice: 0.6377 | IoU: 0.5085 | Acc: 90.72%
# --> New best model saved! (Dice: 0.6377)
#
# Epoch 2/75
# Training: 100%|██████████| 736/736 [06:43<00:00,  1.83it/s, loss=0.332]
# Train Loss: 0.5295 | Val Loss: 0.2228
# Dice: 0.8688 | IoU: 0.7809 | Acc: 97.64%
# --> New best model saved! (Dice: 0.8688)
#
# Epoch 3/75
# Training: 100%|██████████| 736/736 [06:55<00:00,  1.77it/s, loss=0.63]
# Train Loss: 0.4500 | Val Loss: 0.1950
# Dice: 0.8810 | IoU: 0.8015 | Acc: 97.98%
# --> New best model saved! (Dice: 0.8810)
#
# Epoch 4/75
# Training: 100%|██████████| 736/736 [06:55<00:00,  1.77it/s, loss=0.246]
# Train Loss: 0.4109 | Val Loss: 0.2204
# Dice: 0.8675 | IoU: 0.7870 | Acc: 97.71%
#
# Epoch 5/75
# Training: 100%|██████████| 736/736 [06:52<00:00,  1.78it/s, loss=0.356]
# Train Loss: 0.3823 | Val Loss: 0.2100
# Dice: 0.8726 | IoU: 0.7941 | Acc: 97.78%
#
# Epoch 6/75
# Training: 100%|██████████| 736/736 [06:47<00:00,  1.81it/s, loss=0.334]
# Train Loss: 0.3736 | Val Loss: 0.1699
# Dice: 0.9018 | IoU: 0.8304 | Acc: 98.27%
# --> New best model saved! (Dice: 0.9018)
#
# Epoch 7/75
# Training: 100%|██████████| 736/736 [06:50<00:00,  1.79it/s, loss=0.407]
# Train Loss: 0.3458 | Val Loss: 0.1844
# Dice: 0.8879 | IoU: 0.8146 | Acc: 98.18%
#
# Epoch 8/75
# Training: 100%|██████████| 736/736 [06:56<00:00,  1.77it/s, loss=0.449]
# Train Loss: 0.3369 | Val Loss: 0.3426
# Dice: 0.8163 | IoU: 0.7172 | Acc: 96.17%
#
# Epoch 9/75
# Training: 100%|██████████| 736/736 [06:52<00:00,  1.79it/s, loss=0.35]
# Train Loss: 0.3196 | Val Loss: 0.1783
# Dice: 0.8892 | IoU: 0.8162 | Acc: 98.16%
#
# Epoch 10/75
# Training: 100%|██████████| 736/736 [06:51<00:00,  1.79it/s, loss=0.664]
# Train Loss: 0.3115 | Val Loss: 0.1266
# Dice: 0.9287 | IoU: 0.8703 | Acc: 98.65%
# --> New best model saved! (Dice: 0.9287)
#
# Epoch 11/75
# Training: 100%|██████████| 736/736 [06:58<00:00,  1.76it/s, loss=0.403]
# Train Loss: 0.2976 | Val Loss: 0.1331
# Dice: 0.9235 | IoU: 0.8620 | Acc: 98.58%
#
# Epoch 12/75
# Training: 100%|██████████| 736/736 [06:58<00:00,  1.76it/s, loss=0.167]
# Train Loss: 0.2906 | Val Loss: 0.1889
# Dice: 0.8830 | IoU: 0.8155 | Acc: 98.06%
#
# Epoch 13/75
# Training: 100%|██████████| 736/736 [06:54<00:00,  1.78it/s, loss=0.407]
# Train Loss: 0.2906 | Val Loss: 0.1355
# Dice: 0.9204 | IoU: 0.8626 | Acc: 98.62%
#
# Epoch 14/75
# Training: 100%|██████████| 736/736 [06:42<00:00,  1.83it/s, loss=0.276]
# Train Loss: 0.2790 | Val Loss: 0.1220
# Dice: 0.9277 | IoU: 0.8736 | Acc: 98.74%
#
# Epoch 15/75
# Training: 100%|██████████| 736/736 [06:52<00:00,  1.78it/s, loss=0.194]
# Train Loss: 0.2680 | Val Loss: 0.1211
# Dice: 0.9283 | IoU: 0.8723 | Acc: 98.73%
#
# Epoch 16/75
# Training: 100%|██████████| 736/736 [06:47<00:00,  1.81it/s, loss=0.255]
# Train Loss: 0.2658 | Val Loss: 0.1327
# Dice: 0.9211 | IoU: 0.8628 | Acc: 98.62%
#
# Epoch 17/75
# Training: 100%|██████████| 736/736 [06:48<00:00,  1.80it/s, loss=0.244]
# Train Loss: 0.2593 | Val Loss: 0.0989
# Dice: 0.9429 | IoU: 0.8948 | Acc: 98.94%
# --> New best model saved! (Dice: 0.9429)
#
# Epoch 18/75
# Training: 100%|██████████| 736/736 [06:46<00:00,  1.81it/s, loss=0.174]
# Train Loss: 0.2597 | Val Loss: 0.1341
# Dice: 0.9199 | IoU: 0.8628 | Acc: 98.65%
#
# Epoch 19/75
# Training: 100%|██████████| 736/736 [06:55<00:00,  1.77it/s, loss=0.255]
# Train Loss: 0.2579 | Val Loss: 0.1184
# Dice: 0.9290 | IoU: 0.8747 | Acc: 98.76%
#
# Epoch 20/75
# Training: 100%|██████████| 736/736 [06:57<00:00,  1.76it/s, loss=0.227]
# Train Loss: 0.2452 | Val Loss: 0.1051
# Dice: 0.9393 | IoU: 0.8893 | Acc: 98.88%
#
# Epoch 21/75
# Training: 100%|██████████| 736/736 [06:55<00:00,  1.77it/s, loss=0.234]
# Train Loss: 0.2440 | Val Loss: 0.1169
# Dice: 0.9286 | IoU: 0.8758 | Acc: 98.83%
#
# Epoch 22/75
# Training: 100%|██████████| 736/736 [06:52<00:00,  1.78it/s, loss=0.259]
# Train Loss: 0.2398 | Val Loss: 0.1177
# Dice: 0.9307 | IoU: 0.8776 | Acc: 98.80%
#
# Epoch 23/75
# Training: 100%|██████████| 736/736 [06:41<00:00,  1.83it/s, loss=0.586]
# Train Loss: 0.2439 | Val Loss: 0.1633
# Dice: 0.9058 | IoU: 0.8456 | Acc: 98.37%
#
# Epoch 24/75
# Training: 100%|██████████| 736/736 [06:55<00:00,  1.77it/s, loss=0.175]
# Train Loss: 0.2402 | Val Loss: 0.1003
# Dice: 0.9419 | IoU: 0.8945 | Acc: 98.93%
#
# Epoch 25/75
# Training: 100%|██████████| 736/736 [06:46<00:00,  1.81it/s, loss=0.26]
# Train Loss: 0.2365 | Val Loss: 0.1096
# Dice: 0.9369 | IoU: 0.8860 | Acc: 98.86%
#
# Epoch 26/75
# Training: 100%|██████████| 736/736 [06:55<00:00,  1.77it/s, loss=0.268]
# Train Loss: 0.2330 | Val Loss: 0.0977
# Dice: 0.9420 | IoU: 0.8945 | Acc: 98.97%
#
# Epoch 27/75
# Training: 100%|██████████| 736/736 [06:54<00:00,  1.78it/s, loss=0.225]
# Train Loss: 0.2308 | Val Loss: 0.1059
# Dice: 0.9381 | IoU: 0.8887 | Acc: 98.91%
#
# Epoch 28/75
# Training: 100%|██████████| 736/736 [06:52<00:00,  1.78it/s, loss=0.202]
# Train Loss: 0.2285 | Val Loss: 0.1447
# Dice: 0.9182 | IoU: 0.8629 | Acc: 98.60%
#
# Epoch 29/75
# Training: 100%|██████████| 736/736 [06:53<00:00,  1.78it/s, loss=0.22]
# Train Loss: 0.2286 | Val Loss: 0.1036
# Dice: 0.9395 | IoU: 0.8915 | Acc: 98.93%
#
# Epoch 30/75
# Training: 100%|██████████| 736/736 [06:59<00:00,  1.76it/s, loss=0.176]
# Train Loss: 0.2232 | Val Loss: 0.1044
# Dice: 0.9394 | IoU: 0.8896 | Acc: 98.92%
#
# Epoch 31/75
# Training: 100%|██████████| 736/736 [06:57<00:00,  1.76it/s, loss=0.246]
# Train Loss: 0.2228 | Val Loss: 0.2450
# Dice: 0.8597 | IoU: 0.7800 | Acc: 97.60%
#
# Epoch 32/75
# Training: 100%|██████████| 736/736 [06:54<00:00,  1.77it/s, loss=0.25]
# Train Loss: 0.2207 | Val Loss: 0.0993
# Dice: 0.9418 | IoU: 0.8948 | Acc: 98.97%
#
# Epoch 33/75
# Training: 100%|██████████| 736/736 [06:46<00:00,  1.81it/s, loss=0.14]
# Train Loss: 0.2224 | Val Loss: 0.0983
# Dice: 0.9427 | IoU: 0.8957 | Acc: 98.97%
#
# Epoch 34/75
# Training: 100%|██████████| 736/736 [06:54<00:00,  1.78it/s, loss=0.211]
# Train Loss: 0.2162 | Val Loss: 0.1223
# Dice: 0.9279 | IoU: 0.8724 | Acc: 98.75%
#
# Epoch 35/75
# Training: 100%|██████████| 736/736 [06:47<00:00,  1.81it/s, loss=0.129]
# Train Loss: 0.2136 | Val Loss: 0.1022
# Dice: 0.9417 | IoU: 0.8931 | Acc: 98.91%
#
# Epoch 36/75
# Training: 100%|██████████| 736/736 [06:53<00:00,  1.78it/s, loss=0.214]
# Train Loss: 0.2157 | Val Loss: 0.1005
# Dice: 0.9415 | IoU: 0.8946 | Acc: 98.95%
#
# Epoch 37/75
# Training: 100%|██████████| 736/736 [06:50<00:00,  1.79it/s, loss=0.202]
# Train Loss: 0.2197 | Val Loss: 0.1464
# Dice: 0.9179 | IoU: 0.8622 | Acc: 98.57%
#
# Epoch 38/75
# Training: 100%|██████████| 736/736 [06:55<00:00,  1.77it/s, loss=0.113]
# Train Loss: 0.2091 | Val Loss: 0.1192
# Dice: 0.9277 | IoU: 0.8762 | Acc: 98.81%
#
# Epoch 39/75
# Training: 100%|██████████| 736/736 [06:49<00:00,  1.80it/s, loss=0.188]
# Train Loss: 0.2114 | Val Loss: 0.0933
# Dice: 0.9466 | IoU: 0.9015 | Acc: 99.00%
# --> New best model saved! (Dice: 0.9466)
#
# Epoch 40/75
# Training: 100%|██████████| 736/736 [06:49<00:00,  1.80it/s, loss=0.249]
# Train Loss: 0.2241 | Val Loss: 0.0972
# Dice: 0.9429 | IoU: 0.8963 | Acc: 98.97%
#
# Epoch 41/75
# Training: 100%|██████████| 736/736 [06:48<00:00,  1.80it/s, loss=0.213]
# Train Loss: 0.2073 | Val Loss: 0.1128
# Dice: 0.9333 | IoU: 0.8833 | Acc: 98.87%
#
# Epoch 42/75
# Training: 100%|██████████| 736/736 [06:51<00:00,  1.79it/s, loss=0.176]
# Train Loss: 0.2050 | Val Loss: 0.1020
# Dice: 0.9415 | IoU: 0.8928 | Acc: 98.93%
#
# Epoch 43/75
# Training: 100%|██████████| 736/736 [06:49<00:00,  1.80it/s, loss=0.193]
# Train Loss: 0.2086 | Val Loss: 0.0922
# Dice: 0.9475 | IoU: 0.9020 | Acc: 98.99%
# --> New best model saved! (Dice: 0.9475)
#
# Epoch 44/75
# Training: 100%|██████████| 736/736 [06:58<00:00,  1.76it/s, loss=0.171]
# Train Loss: 0.2010 | Val Loss: 0.0943
# Dice: 0.9465 | IoU: 0.9014 | Acc: 98.98%
#
# Epoch 45/75
# Training: 100%|██████████| 736/736 [06:51<00:00,  1.79it/s, loss=0.201]
# Train Loss: 0.2016 | Val Loss: 0.0970
# Dice: 0.9446 | IoU: 0.8982 | Acc: 98.98%
#
# Epoch 46/75
# Training: 100%|██████████| 736/736 [06:44<00:00,  1.82it/s, loss=0.172]
# Train Loss: 0.2030 | Val Loss: 0.1166
# Dice: 0.9333 | IoU: 0.8826 | Acc: 98.82%
#
# Epoch 47/75
# Training: 100%|██████████| 736/736 [06:49<00:00,  1.80it/s, loss=0.16]
# Train Loss: 0.1997 | Val Loss: 0.0960
# Dice: 0.9448 | IoU: 0.8994 | Acc: 99.00%
#
# Epoch 48/75
# Training: 100%|██████████| 736/736 [06:46<00:00,  1.81it/s, loss=0.148]
# Train Loss: 0.1988 | Val Loss: 0.1100
# Dice: 0.9345 | IoU: 0.8856 | Acc: 98.90%
#
# Epoch 49/75
# Training: 100%|██████████| 736/736 [06:46<00:00,  1.81it/s, loss=0.135]
# Train Loss: 0.2008 | Val Loss: 0.1051
# Dice: 0.9391 | IoU: 0.8910 | Acc: 98.90%
#
# Epoch 50/75
# Training: 100%|██████████| 736/736 [06:51<00:00,  1.79it/s, loss=0.385]
# Train Loss: 0.1977 | Val Loss: 0.0932
# Dice: 0.9472 | IoU: 0.9028 | Acc: 99.03%
#
# Epoch 51/75
# Training: 100%|██████████| 736/736 [06:56<00:00,  1.77it/s, loss=0.141]
# Train Loss: 0.1946 | Val Loss: 0.0945
# Dice: 0.9454 | IoU: 0.9004 | Acc: 99.01%
#
# Epoch 52/75
# Training: 100%|██████████| 736/736 [06:53<00:00,  1.78it/s, loss=0.235]
# Train Loss: 0.2221 | Val Loss: 0.0936
# Dice: 0.9462 | IoU: 0.9019 | Acc: 99.02%
#
# Epoch 53/75
# Training: 100%|██████████| 736/736 [06:50<00:00,  1.79it/s, loss=0.177]
# Train Loss: 0.1945 | Val Loss: 0.1951
# Dice: 0.8910 | IoU: 0.8248 | Acc: 98.08%
#
# Epoch 54/75
# Training: 100%|██████████| 736/736 [06:47<00:00,  1.81it/s, loss=0.193]
# Train Loss: 0.1946 | Val Loss: 0.0941
# Dice: 0.9450 | IoU: 0.9014 | Acc: 99.04%
#
# Epoch 55/75
# Training: 100%|██████████| 736/736 [06:47<00:00,  1.81it/s, loss=0.188]
# Train Loss: 0.1962 | Val Loss: 0.0948
# Dice: 0.9449 | IoU: 0.8997 | Acc: 99.02%
#
# Epoch 56/75
# Training: 100%|██████████| 736/736 [06:52<00:00,  1.78it/s, loss=0.211]
# Train Loss: 0.1965 | Val Loss: 0.0961
# Dice: 0.9448 | IoU: 0.8994 | Acc: 99.01%
#
# Epoch 57/75
# Training: 100%|██████████| 736/736 [06:50<00:00,  1.79it/s, loss=0.184]
# Train Loss: 0.1905 | Val Loss: 0.0940
# Dice: 0.9452 | IoU: 0.8994 | Acc: 99.01%
#
# Epoch 58/75
# Training: 100%|██████████| 736/736 [06:49<00:00,  1.80it/s, loss=0.123]
# Train Loss: 0.1922 | Val Loss: 0.1009
# Dice: 0.9418 | IoU: 0.8954 | Acc: 98.98%
#
# Epoch 59/75
# Training: 100%|██████████| 736/736 [06:48<00:00,  1.80it/s, loss=0.197]
# Train Loss: 0.1896 | Val Loss: 0.1065
# Dice: 0.9381 | IoU: 0.8919 | Acc: 98.95%
#
# Epoch 60/75
# Training: 100%|██████████| 736/736 [06:47<00:00,  1.80it/s, loss=0.21]
# Train Loss: 0.1884 | Val Loss: 0.1346
# Dice: 0.9234 | IoU: 0.8684 | Acc: 98.67%
#
# Epoch 61/75
# Training: 100%|██████████| 736/736 [06:56<00:00,  1.77it/s, loss=0.263]
# Train Loss: 0.1857 | Val Loss: 0.0910
# Dice: 0.9480 | IoU: 0.9041 | Acc: 99.06%
# --> New best model saved! (Dice: 0.9480)
#
# Epoch 62/75
# Training: 100%|██████████| 736/736 [06:57<00:00,  1.76it/s, loss=0.183]
# Train Loss: 0.1855 | Val Loss: 0.0953
# Dice: 0.9449 | IoU: 0.9000 | Acc: 99.04%
#
# Epoch 63/75
# Training: 100%|██████████| 736/736 [06:54<00:00,  1.78it/s, loss=0.238]
# Train Loss: 0.1877 | Val Loss: 0.1038
# Dice: 0.9393 | IoU: 0.8928 | Acc: 98.97%
#
# Epoch 64/75
# Training: 100%|██████████| 736/736 [07:00<00:00,  1.75it/s, loss=0.181]
# Train Loss: 0.1847 | Val Loss: 0.1142
# Dice: 0.9374 | IoU: 0.8892 | Acc: 98.87%
#
# Epoch 65/75
# Training: 100%|██████████| 736/736 [07:01<00:00,  1.75it/s, loss=0.229]
# Train Loss: 0.1836 | Val Loss: 0.0925
# Dice: 0.9464 | IoU: 0.9021 | Acc: 99.05%
#
# Epoch 66/75
# Training: 100%|██████████| 736/736 [06:56<00:00,  1.77it/s, loss=0.24]
# Train Loss: 0.1836 | Val Loss: 0.1253
# Dice: 0.9288 | IoU: 0.8781 | Acc: 98.79%
#
# Epoch 67/75
# Training: 100%|██████████| 736/736 [06:48<00:00,  1.80it/s, loss=0.159]
# Train Loss: 0.1934 | Val Loss: 0.0871
# Dice: 0.9500 | IoU: 0.9073 | Acc: 99.08%
# --> New best model saved! (Dice: 0.9500)
#
# Epoch 68/75
# Training: 100%|██████████| 736/736 [06:50<00:00,  1.79it/s, loss=0.163]
# Train Loss: 0.1844 | Val Loss: 0.1111
# Dice: 0.9369 | IoU: 0.8892 | Acc: 98.92%
#
# Epoch 69/75
# Training: 100%|██████████| 736/736 [06:53<00:00,  1.78it/s, loss=0.109]
# Train Loss: 0.1825 | Val Loss: 0.0913
# Dice: 0.9475 | IoU: 0.9040 | Acc: 99.06%
#
# Epoch 70/75
# Training: 100%|██████████| 736/736 [06:49<00:00,  1.80it/s, loss=0.205]
# Train Loss: 0.1833 | Val Loss: 0.0892
# Dice: 0.9484 | IoU: 0.9056 | Acc: 99.10%
#
# Epoch 71/75
# Training: 100%|██████████| 736/736 [06:50<00:00,  1.79it/s, loss=0.196]
# Train Loss: 0.1822 | Val Loss: 0.1109
# Dice: 0.9367 | IoU: 0.8895 | Acc: 98.91%
#
# Epoch 72/75
# Training: 100%|██████████| 736/736 [06:55<00:00,  1.77it/s, loss=0.187]
# Train Loss: 0.1819 | Val Loss: 0.0955
# Dice: 0.9451 | IoU: 0.9017 | Acc: 99.01%
#
# Epoch 73/75
# Training: 100%|██████████| 736/736 [06:45<00:00,  1.82it/s, loss=0.175]
# Train Loss: 0.1826 | Val Loss: 0.1001
# Dice: 0.9422 | IoU: 0.8971 | Acc: 99.01%
#
# Epoch 74/75
# Training: 100%|██████████| 736/736 [06:54<00:00,  1.77it/s, loss=0.163]
# Train Loss: 0.1832 | Val Loss: 0.0938
# Dice: 0.9465 | IoU: 0.9029 | Acc: 99.06%
#
# Epoch 75/75
# Training: 100%|██████████| 736/736 [07:01<00:00,  1.75it/s, loss=0.108]
# Train Loss: 0.1772 | Val Loss: 0.1164
# Dice: 0.9335 | IoU: 0.8871 | Acc: 98.90%

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# --- CONFIGURATION ---
CSV_FILE = "/kaggle/working/training_log.csv"
OUTPUT_IMAGE = "metrics_plot.png"

def plot_training_metrics(csv_file, output_file):
    # 1. Load Data
    try:
        df = pd.read_csv(csv_file)
    except FileNotFoundError:
        print(f"Error: Could not find {csv_file}. Make sure you have run the training script first.")
        return

    # 2. Set "Aesthetic" Style (Seaborn)
    sns.set_theme(style="whitegrid", context="paper", font_scale=1.2)
    
    # Create a figure with a 2x3 grid
    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
    fig.suptitle('Training & Validation Metrics', fontsize=20, fontweight='bold', y=0.98)

    # --- PLOT 1: LOSS (Train vs Val) ---
    sns.lineplot(ax=axes[0, 0], data=df, x='epoch', y='train_loss', label='Train Loss', 
                 linewidth=2.5, color='#E74C3C', marker='o')
    sns.lineplot(ax=axes[0, 0], data=df, x='epoch', y='val_loss', label='Val Loss', 
                 linewidth=2.5, color='#2E86C1', marker='o')
    axes[0, 0].set_title('Loss Curves', fontweight='bold')
    axes[0, 0].set_ylabel('Loss')
    axes[0, 0].legend()

    # --- PLOT 2: DICE & IoU (The most important segmentation metrics) ---
    sns.lineplot(ax=axes[0, 1], data=df, x='epoch', y='dice', label='Dice Score', 
                 linewidth=2.5, color='#27AE60', marker='s')
    sns.lineplot(ax=axes[0, 1], data=df, x='epoch', y='iou', label='IoU Score', 
                 linewidth=2.5, color='#F39C12', marker='s')
    axes[0, 1].set_title('Segmentation Performance (Dice & IoU)', fontweight='bold')
    axes[0, 1].set_ylabel('Score (0-1)')
    axes[0, 1].legend()

    # --- PLOT 3: ACCURACY ---
    sns.lineplot(ax=axes[0, 2], data=df, x='epoch', y='accuracy', 
                 linewidth=2.5, color='#8E44AD', marker='D')
    axes[0, 2].set_title('Pixel Accuracy (%)', fontweight='bold')
    axes[0, 2].set_ylabel('Accuracy (%)')

    # --- PLOT 4: PRECISION vs RECALL ---
    sns.lineplot(ax=axes[1, 0], data=df, x='epoch', y='precision', label='Precision', 
                 linewidth=2.5, color='#16A085', marker='^')
    sns.lineplot(ax=axes[1, 0], data=df, x='epoch', y='recall', label='Recall', 
                 linewidth=2.5, color='#C0392B', marker='v')
    axes[1, 0].set_title('Precision vs Recall', fontweight='bold')
    axes[1, 0].set_ylabel('Score (0-1)')
    axes[1, 0].legend()

    # --- PLOT 5: DICE vs LOSS (Correlation check) ---
    # Helps see if Loss going down actually improves Dice
    ax2 = axes[1, 1].twinx()
    sns.lineplot(ax=axes[1, 1], data=df, x='epoch', y='val_loss', color='#2E86C1', 
                 label='Val Loss', legend=False, linestyle='--')
    sns.lineplot(ax=ax2, data=df, x='epoch', y='dice', color='#27AE60', 
                 label='Dice', legend=False, linewidth=2.5)
    
    axes[1, 1].set_title('Correlation: Val Loss (Blue) vs Dice (Green)', fontweight='bold')
    axes[1, 1].set_ylabel('Val Loss')
    ax2.set_ylabel('Dice Score')
    
    # --- PLOT 6: DATA TABLE (Summary) ---
    axes[1, 2].axis('off')
    # Create a concise table of the best epoch
    best_epoch_idx = df['dice'].idxmax()
    best_row = df.iloc[best_epoch_idx]
    
    table_text = [
        ["Metric", "Best Value"],
        ["Best Epoch", int(best_row['epoch'])],
        ["Dice Score", f"{best_row['dice']:.4f}"],
        ["IoU Score", f"{best_row['iou']:.4f}"],
        ["Precision", f"{best_row['precision']:.4f}"],
        ["Recall", f"{best_row['recall']:.4f}"],
        ["Val Loss", f"{best_row['val_loss']:.4f}"],
    ]
    
    table = axes[1, 2].table(cellText=table_text, loc='center', cellLoc='center', 
                             colWidths=[0.4, 0.4])
    table.auto_set_font_size(False)
    table.set_fontsize(12)
    table.scale(1, 2) # Make rows taller
    axes[1, 2].set_title(f"Best Model Summary (Epoch {int(best_row['epoch'])})", fontweight='bold')

    # Final Layout Adjustments
    plt.tight_layout()
    plt.subplots_adjust(top=0.92) # Make space for main title
    
    # Save
    plt.savefig(output_file, dpi=300, bbox_inches='tight')
    print(f"✅ Plots saved successfully to {output_file}")
    plt.show()

if __name__ == "__main__":
    plot_training_metrics(CSV_FILE, OUTPUT_IMAGE)
# Out:
# ✅ Plots saved successfully to metrics_plot.png

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F  # Added missing import
import numpy as np
import cv2
import matplotlib.pyplot as plt
import albumentations as A
from albumentations.pytorch import ToTensorV2

# --- 2. CONFIGURATION ---
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
CHECKPOINT_PATH = "/kaggle/working/best_checkpoint.pth.tar"
# Replace with a valid image path from your dataset
IMAGE_PATH = "/kaggle/working/datasets/train/images/10000.jpg" 
INPUT_SIZE = 256 

# --- 3. INFERENCE UTILS ---
def load_model(checkpoint_path):
    print(f"Loading model from {checkpoint_path}...")
    model = ResAttUNet(in_channels=3, out_channels=1).to(DEVICE)
    checkpoint = torch.load(checkpoint_path, map_location=DEVICE)
    model.load_state_dict(checkpoint["state_dict"])
    model.eval()
    return model

def predict_single_image(model, image_path):
    # 1. Read Image
    original_img = cv2.imread(image_path)
    if original_img is None:
        raise ValueError(f"Image not found at {image_path}")
    
    original_rgb = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)
    
    # 2. Preprocess
    transform = A.Compose([
        A.Resize(height=INPUT_SIZE, width=INPUT_SIZE),
        A.Normalize(mean=[0.0, 0.0, 0.0], std=[1.0, 1.0, 1.0], max_pixel_value=255.0),
        ToTensorV2(),
    ])
    
    augmented = transform(image=original_rgb)
    img_tensor = augmented["image"].unsqueeze(0).to(DEVICE)
    
    # 3. Inference
    with torch.no_grad():
        outputs = model(img_tensor) # This returns a list: [final, mid, coarse]
        
        # --- FIX IS HERE: Take index 0 ---
        logits = outputs[0] 
        
        probs = torch.sigmoid(logits)
        mask = (probs > 0.5).float()
    
    # 4. Post-processing
    mask_np = mask.squeeze().cpu().numpy()
    original_h, original_w = original_rgb.shape[:2]
    mask_resized = cv2.resize(mask_np, (original_w, original_h), interpolation=cv2.INTER_NEAREST)
    
    return original_rgb, mask_resized

def visualize_result(image, mask):
    mask_colored = np.zeros_like(image)
    mask_colored[:, :, 0] = 255 # Red
    mask_indices = mask > 0
    overlay = image.copy()
    overlay[mask_indices] = cv2.addWeighted(image[mask_indices], 0.5, mask_colored[mask_indices], 0.5, 0)

    fig, ax = plt.subplots(1, 3, figsize=(15, 5))
    ax[0].imshow(image); ax[0].set_title("Original Satellite Image"); ax[0].axis("off")
    ax[1].imshow(mask, cmap="gray"); ax[1].set_title("Predicted Segmentation Mask"); ax[1].axis("off")
    ax[2].imshow(overlay); ax[2].set_title("Overlay (Red = Rooftop)"); ax[2].axis("off")
    plt.tight_layout()
    plt.show()

# --- MAIN EXECUTION ---
if __name__ == "__main__":
    model = load_model(CHECKPOINT_PATH)
    try:
        img, pred_mask = predict_single_image(model, IMAGE_PATH)
        visualize_result(img, pred_mask)
        print("Inference Complete!")
    except Exception as e:
        print(f"Error: {e}")
# Out:
# Loading model from /kaggle/working/best_checkpoint.pth.tar...
# Inference Complete!
