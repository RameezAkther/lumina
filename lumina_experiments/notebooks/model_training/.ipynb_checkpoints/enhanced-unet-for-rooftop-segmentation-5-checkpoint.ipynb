# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ResidualBlock(nn.Module):
    """
    Novelty 1: Residual Block
    Replaces standard double conv. Helps in training deeper networks 
    and preserving feature identity.
    """
    def __init__(self, in_c, out_c):
        super().__init__()
        self.conv1 = nn.Conv2d(in_c, out_c, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(out_c)
        self.conv2 = nn.Conv2d(out_c, out_c, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(out_c)
        
        # Shortcut connection to match dimensions
        self.shortcut = nn.Sequential()
        if in_c != out_c:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_c, out_c, kernel_size=1, padding=0),
                nn.BatchNorm2d(out_c)
            )

    def forward(self, x):
        shortcut = self.shortcut(x)
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.bn2(self.conv2(x))
        x += shortcut  # The "Residual" connection
        return F.relu(x)

class AttentionGate(nn.Module):
    """
    Novelty 2: Attention Gate
    Filters the skip connection features. It uses the coarser signal 
    from the decoder (g) to highlight relevant regions in the encoder features (x).
    """
    def __init__(self, in_c, gate_c, inter_c):
        super().__init__()
        # W_g: Transform gating signal
        self.Wg = nn.Sequential(
            nn.Conv2d(gate_c, inter_c, kernel_size=1, padding=0),
            nn.BatchNorm2d(inter_c)
        )
        # W_x: Transform skip connection
        self.Wx = nn.Sequential(
            nn.Conv2d(in_c, inter_c, kernel_size=1, padding=0),
            nn.BatchNorm2d(inter_c)
        )
        # Psi: Combine and activate
        self.psi = nn.Sequential(
            nn.Conv2d(inter_c, 1, kernel_size=1, padding=0),
            nn.BatchNorm2d(1),
            nn.Sigmoid()
        )
        
    def forward(self, x, g):
        g1 = self.Wg(g)
        x1 = self.Wx(x)
        psi = F.relu(g1 + x1)
        psi = self.psi(psi)
        return x * psi  # Scale the skip connection by the attention map

class ResAttUNet(nn.Module):
    def __init__(self, in_channels=3, out_channels=1):
        super().__init__()
        
        # --- Encoder (Downsampling) ---
        self.e1 = ResidualBlock(in_channels, 64)
        self.e2 = ResidualBlock(64, 128)
        self.e3 = ResidualBlock(128, 256)
        self.e4 = ResidualBlock(256, 512)
        
        self.pool = nn.MaxPool2d(2, 2)
        
        # --- Bridge ---
        self.b = ResidualBlock(512, 1024)
        
        # --- Decoder (Upsampling + Attention) ---
        
        # Up 1
        self.up1 = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.att1 = AttentionGate(in_c=512, gate_c=1024, inter_c=256)
        self.d1 = ResidualBlock(1024 + 512, 512)
        
        # Up 2
        self.up2 = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.att2 = AttentionGate(in_c=256, gate_c=512, inter_c=128)
        self.d2 = ResidualBlock(512 + 256, 256)
        
        # [NEW] Deep Supervision Output 2 (from 256 channels)
        self.ds_out3 = nn.Conv2d(256, out_channels, kernel_size=1) 
        
        # Up 3
        self.up3 = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.att3 = AttentionGate(in_c=128, gate_c=256, inter_c=64)
        self.d3 = ResidualBlock(256 + 128, 128)

        # [NEW] Deep Supervision Output 3 (from 128 channels)
        self.ds_out2 = nn.Conv2d(128, out_channels, kernel_size=1)
        
        # Up 4
        self.up4 = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.att4 = AttentionGate(in_c=64, gate_c=128, inter_c=32)
        self.d4 = ResidualBlock(128 + 64, 64)
        
        # Output (Final)
        self.out = nn.Conv2d(64, out_channels, kernel_size=1)
        
    def forward(self, x):
        # Encoder
        x1 = self.e1(x)
        p1 = self.pool(x1)
        
        x2 = self.e2(p1)
        p2 = self.pool(x2)
        
        x3 = self.e3(p2)
        p3 = self.pool(x3)
        
        x4 = self.e4(p3)
        p4 = self.pool(x4)
        
        # Bridge
        b = self.b(p4)
        
        # Decoder
        
        # Block 1
        d1 = self.up1(b)
        x4 = self.att1(x=x4, g=d1)
        d1 = torch.cat((x4, d1), dim=1)
        d1 = self.d1(d1)
        
        # Block 2
        d2 = self.up2(d1)
        x3 = self.att2(x=x3, g=d2)
        d2 = torch.cat((x3, d2), dim=1)
        d2 = self.d2(d2)
        # [NEW] Capture Intermediate Output (1/4 resolution)
        out3 = self.ds_out3(d2)

        # Block 3
        d3 = self.up3(d2)
        x2 = self.att3(x=x2, g=d3)
        d3 = torch.cat((x2, d3), dim=1)
        d3 = self.d3(d3)
        # [NEW] Capture Intermediate Output (1/2 resolution)
        out2 = self.ds_out2(d3)
        
        # Block 4
        d4 = self.up4(d3)
        x1 = self.att4(x=x1, g=d4)
        d4 = torch.cat((x1, d4), dim=1)
        d4 = self.d4(d4)
        
        # Final Output
        out_final = self.out(d4)
        
        # [NEW] Return List: [Final, Middle, Coarse]
        # We must upsample the smaller maps to match the input size for Loss calculation
        return [
            out_final,
            F.interpolate(out2, scale_factor=2, mode='bilinear', align_corners=True),
            F.interpolate(out3, scale_factor=4, mode='bilinear', align_corners=True)
        ]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class DiceBCELoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(DiceBCELoss, self).__init__()

    def forward(self, inputs, targets, smooth=1):
        # inputs are LOGITS (raw output from model, no sigmoid yet)
        
        # --- 1. BCE Loss (Must use logits for stability in AMP) ---
        # binary_cross_entropy_with_logits includes the sigmoid internally
        bce_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduction='mean')
        
        # --- 2. Dice Loss (Needs probabilities 0-1) ---
        # We manually apply sigmoid just for the Dice calculation
        inputs_prob = torch.sigmoid(inputs)
        
        # Flatten for Dice math
        inputs_flat = inputs_prob.view(-1)
        targets_flat = targets.view(-1)
        
        intersection = (inputs_flat * targets_flat).sum()                            
        dice_loss = 1 - (2.*intersection + smooth)/(inputs_flat.sum() + targets_flat.sum() + smooth)  
        
        return bce_loss + dice_loss

# %%
import os
import cv2
import csv
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import albumentations as A 
from albumentations.pytorch import ToTensorV2
from tqdm import tqdm 

# --- IMPORT YOUR MODEL & LOSS ---
# # Ensure model.py and loss.py are in the same directory
# from model import ResAttUNet 
# from loss import DiceBCELoss 

# ==========================================
# 1. CONFIGURATION
# ==========================================
LEARNING_RATE = 1e-4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATCH_SIZE = 4 
NUM_EPOCHS = 200
NUM_WORKERS = 2

# Inria images are 5000x5000. We must crop them during training.
IMAGE_HEIGHT = 512 
IMAGE_WIDTH = 512
PIN_MEMORY = True

# Path to the dataset root
DATASET_ROOT = "/kaggle/input/inria-aerial-image-labeling-dataset/AerialImageDataset/train"
IMG_DIR = os.path.join(DATASET_ROOT, "images")
GT_DIR = os.path.join(DATASET_ROOT, "gt")

CSV_FILE = "training_log.csv" 

# ==========================================
# 2. DATASET CLASS (INRIA SPECIFIC)
# ==========================================
class InriaDataset(Dataset):
    def __init__(self, img_dir, gt_dir, filenames, transform=None):
        """
        filenames: List of specific files to use (allows manual train/val split)
        """
        self.img_dir = img_dir
        self.gt_dir = gt_dir
        self.filenames = filenames
        self.transform = transform

    def __len__(self):
        return len(self.filenames)

    def __getitem__(self, index):
        filename = self.filenames[index]
        img_path = os.path.join(self.img_dir, filename)
        gt_path = os.path.join(self.gt_dir, filename)

        # 1. Load Image
        image = cv2.imread(img_path)
        if image is None:
             raise FileNotFoundError(f"Image not found: {img_path}")
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # 2. Load Mask
        # Inria GT is usually 0 (background) and 255 (building)
        mask = cv2.imread(gt_path, cv2.IMREAD_GRAYSCALE)
        if mask is None:
             raise FileNotFoundError(f"Mask not found: {gt_path}")
        
        # Normalize to 0.0 and 1.0
        mask = (mask > 127).astype(np.float32) # Threshold to be safe
        
        # 3. Apply Augmentations (Crucial: RandomCrop is handled here)
        if self.transform is not None:
            augmentations = self.transform(image=image, mask=mask)
            image = augmentations["image"]
            mask = augmentations["mask"]

        return image, mask

# ==========================================
# 3. DST STITCHER (Reuse)
# ==========================================
def make_mosaic(images, masks):
    batch_size = images.shape[0]
    if batch_size < 4: return images, masks 

    stitched_imgs = []
    stitched_masks = []

    for i in range(0, batch_size - 3, 4):
        # Resize to half size
        img1 = F.interpolate(images[i].unsqueeze(0), scale_factor=0.5)
        img2 = F.interpolate(images[i+1].unsqueeze(0), scale_factor=0.5)
        img3 = F.interpolate(images[i+2].unsqueeze(0), scale_factor=0.5)
        img4 = F.interpolate(images[i+3].unsqueeze(0), scale_factor=0.5)

        mask1 = F.interpolate(masks[i].unsqueeze(0).unsqueeze(0), scale_factor=0.5)
        mask2 = F.interpolate(masks[i+1].unsqueeze(0).unsqueeze(0), scale_factor=0.5)
        mask3 = F.interpolate(masks[i+2].unsqueeze(0).unsqueeze(0), scale_factor=0.5)
        mask4 = F.interpolate(masks[i+3].unsqueeze(0).unsqueeze(0), scale_factor=0.5)

        # Stitch
        top = torch.cat([img1, img2], dim=3)    
        bot = torch.cat([img3, img4], dim=3)
        final_img = torch.cat([top, bot], dim=2) 

        top_m = torch.cat([mask1, mask2], dim=3)
        bot_m = torch.cat([mask3, mask4], dim=3)
        final_mask = torch.cat([top_m, bot_m], dim=2).squeeze(1)

        stitched_imgs.append(final_img)
        stitched_masks.append(final_mask)

    if len(stitched_imgs) == 0: return images, masks
    return torch.cat(stitched_imgs, dim=0), torch.cat(stitched_masks, dim=0)

# ==========================================
# 4. TRAINING UTILS
# ==========================================
def get_loaders(img_dir, gt_dir, batch_size, train_transform, val_transform, num_workers=4, pin_memory=True):
    
    # 1. Get all valid filenames
    all_files = [f for f in os.listdir(img_dir) if f.endswith('.tif')]
    # Sort to ensure reproducibility
    all_files.sort() 
    
    # 2. Perform Manual Split (e.g., last 10% for validation)
    split_idx = int(len(all_files) * 0.9) # 90% train, 10% val
    train_files = all_files[:split_idx]
    val_files = all_files[split_idx:]
    
    print(f"Total Images: {len(all_files)}")
    print(f"Training on {len(train_files)} images.")
    print(f"Validating on {len(val_files)} images.")

    # 3. Create Datasets
    train_ds = InriaDataset(
        img_dir=img_dir, 
        gt_dir=gt_dir, 
        filenames=train_files,
        transform=train_transform
    )
    
    val_ds = InriaDataset(
        img_dir=img_dir, 
        gt_dir=gt_dir, 
        filenames=val_files,
        transform=val_transform
    )
    
    # 4. Create Loaders
    train_loader = DataLoader(
        train_ds, 
        batch_size=batch_size, 
        num_workers=num_workers, 
        pin_memory=pin_memory, 
        shuffle=True,
    )

    val_loader = DataLoader(
        val_ds, 
        batch_size=batch_size, 
        num_workers=num_workers, 
        pin_memory=pin_memory, 
        shuffle=False,
    )

    return train_loader, val_loader

def evaluate(loader, model, loss_fn, device="cuda"):
    model.eval()
    val_loss = 0
    dice_score = 0
    iou_score = 0
    precision = 0
    recall = 0
    num_correct = 0
    num_pixels = 0
    
    loop = tqdm(loader, desc="Validating", leave=False)

    with torch.no_grad():
        for x, y in loop:
            x = x.to(device)
            y = y.float().to(device).unsqueeze(1) 
            
            outputs = model(x)
            final_pred = outputs[0]
            
            loss = loss_fn(final_pred, y)
            val_loss += loss.item()
            
            preds = torch.sigmoid(final_pred)
            preds = (preds > 0.5).float() 
            
            TP = (preds * y).sum()
            FP = (preds * (1 - y)).sum()
            FN = ((1 - preds) * y).sum()
            
            smooth = 1e-8
            dice_score += (2 * TP) / (2 * TP + FP + FN + smooth)
            iou_score += TP / (TP + FP + FN + smooth)
            precision += TP / (TP + FP + smooth)
            recall += TP / (TP + FN + smooth)
            
            num_correct += (preds == y).sum().item()
            num_pixels += torch.numel(preds)

    length = len(loader)
    return {
        "val_loss": val_loss / length,
        "accuracy": (num_correct / num_pixels) * 100,
        "dice": (dice_score / length).item(),
        "iou": (iou_score / length).item(),
        "precision": (precision / length).item(),
        "recall": (recall / length).item()
    }

def train_fn(loader, model, optimizer, loss_fn, scaler):
    loop = tqdm(loader, desc="Training")
    USE_MOSAIC = False 
    running_loss = 0.0

    for batch_idx, (data, targets) in enumerate(loop):
        data = data.to(DEVICE)
        targets = targets.float().to(DEVICE) 

        if USE_MOSAIC:
            data, targets = make_mosaic(data, targets)
            USE_MOSAIC = False 

        with torch.amp.autocast('cuda'): 
            outputs = model(data) 
            final_pred, mid_pred, coarse_pred = outputs[0], outputs[1], outputs[2]
            
            targets_unsqueezed = targets.unsqueeze(1)
            
            loss_1 = loss_fn(final_pred, targets_unsqueezed)
            loss_2 = loss_fn(mid_pred, targets_unsqueezed)
            loss_3 = loss_fn(coarse_pred, targets_unsqueezed)
            
            total_loss = loss_1 + (0.5 * loss_2) + (0.4 * loss_3)
            
            if torch.rand(1).item() < 0.2: 
                USE_MOSAIC = True

        optimizer.zero_grad()
        scaler.scale(total_loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += total_loss.item()
        loop.set_postfix(loss=total_loss.item())
        
    return running_loss / len(loader)

# ==========================================
# 5. MAIN EXECUTION
# ==========================================
def main():
    # --- TRANSFORMS ---
    # Training: RandomCrop 512x512 from the massive 5000x5000 image
    train_transform = A.Compose([
        A.RandomCrop(height=IMAGE_HEIGHT, width=IMAGE_WIDTH), # Critical for Inria
        A.Rotate(limit=35, p=0.5),
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.5),
        A.Normalize(mean=[0.0, 0.0, 0.0], std=[1.0, 1.0, 1.0], max_pixel_value=255.0),
        ToTensorV2(),
    ])

    # Validation: CenterCrop ensures we always validate on the same area
    # (Alternatively, you could tile the image, but CenterCrop is standard for quick val)
    val_transform = A.Compose([
        A.CenterCrop(height=IMAGE_HEIGHT, width=IMAGE_WIDTH),
        A.Normalize(mean=[0.0, 0.0, 0.0], std=[1.0, 1.0, 1.0], max_pixel_value=255.0),
        ToTensorV2(),
    ])

    # --- INITIALIZE ---
    model = ResAttUNet(in_channels=3, out_channels=1).to(DEVICE)
    loss_fn = DiceBCELoss() 
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
    scaler = torch.amp.GradScaler('cuda')

    # Pass the ROOT directories. The loader handles splitting.
    train_loader, val_loader = get_loaders(
        IMG_DIR, GT_DIR,
        BATCH_SIZE, train_transform, val_transform, NUM_WORKERS, PIN_MEMORY
    )

    # --- CSV SETUP ---
    header = ['epoch', 'train_loss', 'val_loss', 'accuracy', 'dice', 'iou', 'precision', 'recall']
    with open(CSV_FILE, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(header)

    best_dice_score = 0.0

    print(f"Starting training on {DEVICE}...")

    # --- EPOCH LOOP ---
    for epoch in range(NUM_EPOCHS):
        print(f"\nEpoch {epoch+1}/{NUM_EPOCHS}")
        
        avg_train_loss = train_fn(train_loader, model, optimizer, loss_fn, scaler)
        metrics = evaluate(val_loader, model, loss_fn, DEVICE)
        
        print(f"Train Loss: {avg_train_loss:.4f} | Val Loss: {metrics['val_loss']:.4f}")
        print(f"Dice: {metrics['dice']:.4f} | IoU: {metrics['iou']:.4f} | Acc: {metrics['accuracy']:.2f}%")
        
        if metrics['dice'] > best_dice_score:
            best_dice_score = metrics['dice']
            checkpoint = {
                "state_dict": model.state_dict(),
                "optimizer": optimizer.state_dict(),
                "epoch": epoch,
                "best_dice": best_dice_score,
            }
            torch.save(checkpoint, "best_checkpoint.pth.tar")
            print(f"--> New best model saved! (Dice: {best_dice_score:.4f})")
            
        with open(CSV_FILE, 'a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow([
                epoch + 1, avg_train_loss, metrics['val_loss'], metrics['accuracy'], 
                metrics['dice'], metrics['iou'], metrics['precision'], metrics['recall']
            ])

if __name__ == "__main__":
    main()
# Out:
# Total Images: 180
# Training on 162 images.
# Validating on 18 images.
# Starting training on cuda...
#
# Epoch 1/200
# Training: 100%|██████████| 41/41 [01:17<00:00,  1.88s/it, loss=2.55]
# Train Loss: 2.0940 | Val Loss: 1.4671
# Dice: 0.0075 | IoU: 0.0038 | Acc: 73.95%
# --> New best model saved! (Dice: 0.0075)
#
# Epoch 2/200
# Training: 100%|██████████| 41/41 [00:32<00:00,  1.26it/s, loss=2.06]
# Train Loss: 2.2723 | Val Loss: 1.1912
# Dice: 0.3755 | IoU: 0.2323 | Acc: 70.81%
# --> New best model saved! (Dice: 0.3755)
#
# Epoch 3/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=2.17]
# Train Loss: 1.9557 | Val Loss: 1.1241
# Dice: 0.5520 | IoU: 0.3866 | Acc: 67.07%
# --> New best model saved! (Dice: 0.5520)
#
# Epoch 4/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=1.54]
# Train Loss: 1.8362 | Val Loss: 1.1237
# Dice: 0.5602 | IoU: 0.3943 | Acc: 68.95%
# --> New best model saved! (Dice: 0.5602)
#
# Epoch 5/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.41it/s, loss=2.55]
# Train Loss: 1.8663 | Val Loss: 1.1421
# Dice: 0.5625 | IoU: 0.3981 | Acc: 64.85%
# --> New best model saved! (Dice: 0.5625)
#
# Epoch 6/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=2.08]
# Train Loss: 1.7242 | Val Loss: 1.0447
# Dice: 0.5650 | IoU: 0.4006 | Acc: 69.36%
# --> New best model saved! (Dice: 0.5650)
#
# Epoch 7/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.39it/s, loss=1.89]
# Train Loss: 1.6425 | Val Loss: 1.0377
# Dice: 0.5788 | IoU: 0.4137 | Acc: 70.92%
# --> New best model saved! (Dice: 0.5788)
#
# Epoch 8/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.30it/s, loss=1.79]
# Train Loss: 1.5485 | Val Loss: 1.1440
# Dice: 0.5197 | IoU: 0.3619 | Acc: 66.89%
#
# Epoch 9/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.39it/s, loss=1.96]
# Train Loss: 1.6952 | Val Loss: 1.1140
# Dice: 0.4135 | IoU: 0.2641 | Acc: 78.98%
#
# Epoch 10/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=1.76]
# Train Loss: 1.7054 | Val Loss: 1.1147
# Dice: 0.5555 | IoU: 0.3928 | Acc: 63.82%
#
# Epoch 11/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.32it/s, loss=1.62]
# Train Loss: 1.6283 | Val Loss: 0.9591
# Dice: 0.5844 | IoU: 0.4176 | Acc: 80.69%
# --> New best model saved! (Dice: 0.5844)
#
# Epoch 12/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=1.52]
# Train Loss: 1.7406 | Val Loss: 1.0942
# Dice: 0.5633 | IoU: 0.4030 | Acc: 68.78%
#
# Epoch 13/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=1.27]
# Train Loss: 1.6745 | Val Loss: 0.9972
# Dice: 0.5966 | IoU: 0.4321 | Acc: 73.79%
# --> New best model saved! (Dice: 0.5966)
#
# Epoch 14/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.31it/s, loss=1.97]
# Train Loss: 1.5219 | Val Loss: 1.0898
# Dice: 0.5844 | IoU: 0.4231 | Acc: 70.81%
#
# Epoch 15/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=1.19]
# Train Loss: 1.5223 | Val Loss: 0.9534
# Dice: 0.5446 | IoU: 0.3799 | Acc: 80.87%
#
# Epoch 16/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=2.05]
# Train Loss: 1.5258 | Val Loss: 0.9742
# Dice: 0.6038 | IoU: 0.4437 | Acc: 76.90%
# --> New best model saved! (Dice: 0.6038)
#
# Epoch 17/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.37it/s, loss=1.54]
# Train Loss: 1.5408 | Val Loss: 0.9508
# Dice: 0.5747 | IoU: 0.4086 | Acc: 80.29%
#
# Epoch 18/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.31it/s, loss=1.26]
# Train Loss: 1.4601 | Val Loss: 0.9914
# Dice: 0.6096 | IoU: 0.4456 | Acc: 73.91%
# --> New best model saved! (Dice: 0.6096)
#
# Epoch 19/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=0.918]
# Train Loss: 1.3718 | Val Loss: 0.8954
# Dice: 0.6414 | IoU: 0.4779 | Acc: 79.65%
# --> New best model saved! (Dice: 0.6414)
#
# Epoch 20/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=1.82]
# Train Loss: 1.4889 | Val Loss: 0.9791
# Dice: 0.6175 | IoU: 0.4538 | Acc: 74.05%
#
# Epoch 21/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.39it/s, loss=1.13]
# Train Loss: 1.5193 | Val Loss: 0.8935
# Dice: 0.6232 | IoU: 0.4569 | Acc: 80.01%
#
# Epoch 22/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=0.943]
# Train Loss: 1.4020 | Val Loss: 0.9758
# Dice: 0.6154 | IoU: 0.4520 | Acc: 75.34%
#
# Epoch 23/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.31it/s, loss=1.88]
# Train Loss: 1.4855 | Val Loss: 0.9505
# Dice: 0.6114 | IoU: 0.4490 | Acc: 76.12%
#
# Epoch 24/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=1.2]
# Train Loss: 1.3034 | Val Loss: 0.9193
# Dice: 0.6263 | IoU: 0.4626 | Acc: 77.77%
#
# Epoch 25/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.37it/s, loss=1.43]
# Train Loss: 1.3842 | Val Loss: 0.9500
# Dice: 0.6109 | IoU: 0.4487 | Acc: 75.46%
#
# Epoch 26/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=1.03]
# Train Loss: 1.3660 | Val Loss: 0.9053
# Dice: 0.6316 | IoU: 0.4657 | Acc: 78.53%
#
# Epoch 27/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=1.51]
# Train Loss: 1.2796 | Val Loss: 0.8859
# Dice: 0.6248 | IoU: 0.4593 | Acc: 81.03%
#
# Epoch 28/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.38it/s, loss=1.01]
# Train Loss: 1.2664 | Val Loss: 0.8739
# Dice: 0.6352 | IoU: 0.4686 | Acc: 80.61%
#
# Epoch 29/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.39it/s, loss=1.33]
# Train Loss: 1.3040 | Val Loss: 0.9003
# Dice: 0.6297 | IoU: 0.4650 | Acc: 77.02%
#
# Epoch 30/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=0.597]
# Train Loss: 1.2554 | Val Loss: 1.0782
# Dice: 0.6088 | IoU: 0.4457 | Acc: 73.65%
#
# Epoch 31/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.32it/s, loss=1.92]
# Train Loss: 1.2344 | Val Loss: 0.9133
# Dice: 0.6082 | IoU: 0.4398 | Acc: 82.85%
#
# Epoch 32/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=0.867]
# Train Loss: 1.2796 | Val Loss: 0.8332
# Dice: 0.6821 | IoU: 0.5194 | Acc: 82.84%
# --> New best model saved! (Dice: 0.6821)
#
# Epoch 33/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=1.11]
# Train Loss: 1.3241 | Val Loss: 0.9245
# Dice: 0.6584 | IoU: 0.4941 | Acc: 78.33%
#
# Epoch 34/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=1.68]
# Train Loss: 1.2185 | Val Loss: 0.9525
# Dice: 0.6059 | IoU: 0.4366 | Acc: 82.57%
#
# Epoch 35/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.38it/s, loss=1.37]
# Train Loss: 1.3141 | Val Loss: 0.9840
# Dice: 0.6315 | IoU: 0.4732 | Acc: 74.91%
#
# Epoch 36/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=1.33]
# Train Loss: 1.2279 | Val Loss: 0.8064
# Dice: 0.6716 | IoU: 0.5075 | Acc: 82.78%
#
# Epoch 37/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=1.24]
# Train Loss: 1.1635 | Val Loss: 0.8439
# Dice: 0.6824 | IoU: 0.5211 | Acc: 80.04%
# --> New best model saved! (Dice: 0.6824)
#
# Epoch 38/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.40it/s, loss=1.42]
# Train Loss: 1.3808 | Val Loss: 0.8122
# Dice: 0.6764 | IoU: 0.5143 | Acc: 81.60%
#
# Epoch 39/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=1.04]
# Train Loss: 1.2583 | Val Loss: 0.9372
# Dice: 0.6408 | IoU: 0.4799 | Acc: 79.33%
#
# Epoch 40/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=0.945]
# Train Loss: 1.2685 | Val Loss: 0.8716
# Dice: 0.6549 | IoU: 0.4928 | Acc: 79.84%
#
# Epoch 41/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=1.51]
# Train Loss: 1.1496 | Val Loss: 0.9045
# Dice: 0.6397 | IoU: 0.4739 | Acc: 81.98%
#
# Epoch 42/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.38it/s, loss=1.22]
# Train Loss: 1.2298 | Val Loss: 0.7813
# Dice: 0.6924 | IoU: 0.5334 | Acc: 82.55%
# --> New best model saved! (Dice: 0.6924)
#
# Epoch 43/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.28it/s, loss=1.94]
# Train Loss: 1.2536 | Val Loss: 0.9899
# Dice: 0.6485 | IoU: 0.4883 | Acc: 78.52%
#
# Epoch 44/200
# Training: 100%|██████████| 41/41 [00:32<00:00,  1.24it/s, loss=1.91]
# Train Loss: 1.2691 | Val Loss: 0.9175
# Dice: 0.6434 | IoU: 0.4804 | Acc: 76.51%
#
# Epoch 45/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=1.31]
# Train Loss: 1.1285 | Val Loss: 0.9857
# Dice: 0.6367 | IoU: 0.4725 | Acc: 74.85%
#
# Epoch 46/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=1.2]
# Train Loss: 1.2765 | Val Loss: 0.7535
# Dice: 0.7022 | IoU: 0.5428 | Acc: 83.76%
# --> New best model saved! (Dice: 0.7022)
#
# Epoch 47/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=1.45]
# Train Loss: 1.2552 | Val Loss: 0.7425
# Dice: 0.7149 | IoU: 0.5581 | Acc: 83.72%
# --> New best model saved! (Dice: 0.7149)
#
# Epoch 48/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.39it/s, loss=1.09]
# Train Loss: 1.1020 | Val Loss: 0.7914
# Dice: 0.6787 | IoU: 0.5173 | Acc: 82.39%
#
# Epoch 49/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.32it/s, loss=0.694]
# Train Loss: 1.1234 | Val Loss: 0.8803
# Dice: 0.6732 | IoU: 0.5137 | Acc: 81.70%
#
# Epoch 50/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=1.39]
# Train Loss: 1.1939 | Val Loss: 0.7775
# Dice: 0.6975 | IoU: 0.5383 | Acc: 82.30%
#
# Epoch 51/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=3.17]
# Train Loss: 1.2296 | Val Loss: 0.7542
# Dice: 0.7067 | IoU: 0.5483 | Acc: 83.24%
#
# Epoch 52/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=2.01]
# Train Loss: 1.2063 | Val Loss: 0.7921
# Dice: 0.6948 | IoU: 0.5368 | Acc: 81.37%
#
# Epoch 53/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.31it/s, loss=1.21]
# Train Loss: 1.1730 | Val Loss: 0.9359
# Dice: 0.6539 | IoU: 0.4907 | Acc: 77.41%
#
# Epoch 54/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=0.864]
# Train Loss: 1.1380 | Val Loss: 0.7940
# Dice: 0.6920 | IoU: 0.5318 | Acc: 82.03%
#
# Epoch 55/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.37it/s, loss=0.992]
# Train Loss: 1.0795 | Val Loss: 0.6916
# Dice: 0.7202 | IoU: 0.5647 | Acc: 85.49%
# --> New best model saved! (Dice: 0.7202)
#
# Epoch 56/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=1.74]
# Train Loss: 1.1450 | Val Loss: 0.7638
# Dice: 0.6790 | IoU: 0.5165 | Acc: 85.33%
#
# Epoch 57/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=0.72]
# Train Loss: 1.1652 | Val Loss: 0.8303
# Dice: 0.6867 | IoU: 0.5266 | Acc: 79.54%
#
# Epoch 58/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.31it/s, loss=0.834]
# Train Loss: 1.0321 | Val Loss: 0.8387
# Dice: 0.6785 | IoU: 0.5201 | Acc: 79.22%
#
# Epoch 59/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=1.3]
# Train Loss: 1.1168 | Val Loss: 0.7319
# Dice: 0.7212 | IoU: 0.5676 | Acc: 83.03%
# --> New best model saved! (Dice: 0.7212)
#
# Epoch 60/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=1.71]
# Train Loss: 1.1537 | Val Loss: 0.7518
# Dice: 0.7078 | IoU: 0.5489 | Acc: 83.88%
#
# Epoch 61/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.39it/s, loss=0.741]
# Train Loss: 1.0677 | Val Loss: 0.8013
# Dice: 0.6787 | IoU: 0.5154 | Acc: 83.08%
#
# Epoch 62/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.38it/s, loss=1.24]
# Train Loss: 1.1241 | Val Loss: 0.7638
# Dice: 0.7021 | IoU: 0.5446 | Acc: 83.32%
#
# Epoch 63/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.32it/s, loss=0.773]
# Train Loss: 1.1326 | Val Loss: 0.7378
# Dice: 0.7057 | IoU: 0.5478 | Acc: 84.79%
#
# Epoch 64/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.37it/s, loss=0.963]
# Train Loss: 1.0930 | Val Loss: 0.7667
# Dice: 0.7076 | IoU: 0.5528 | Acc: 82.25%
#
# Epoch 65/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.32it/s, loss=1.28]
# Train Loss: 1.2168 | Val Loss: 0.6964
# Dice: 0.7254 | IoU: 0.5714 | Acc: 84.70%
# --> New best model saved! (Dice: 0.7254)
#
# Epoch 66/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.37it/s, loss=1.76]
# Train Loss: 1.1801 | Val Loss: 0.6722
# Dice: 0.7362 | IoU: 0.5835 | Acc: 85.95%
# --> New best model saved! (Dice: 0.7362)
#
# Epoch 67/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=0.846]
# Train Loss: 1.1591 | Val Loss: 0.7086
# Dice: 0.7089 | IoU: 0.5508 | Acc: 84.51%
#
# Epoch 68/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=0.673]
# Train Loss: 1.1041 | Val Loss: 0.6672
# Dice: 0.7381 | IoU: 0.5860 | Acc: 85.68%
# --> New best model saved! (Dice: 0.7381)
#
# Epoch 69/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=2.06]
# Train Loss: 1.1503 | Val Loss: 0.9577
# Dice: 0.6599 | IoU: 0.4997 | Acc: 75.47%
#
# Epoch 70/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.30it/s, loss=1.97]
# Train Loss: 1.0710 | Val Loss: 0.7591
# Dice: 0.7220 | IoU: 0.5688 | Acc: 81.64%
#
# Epoch 71/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.28it/s, loss=1.13]
# Train Loss: 1.0175 | Val Loss: 0.7149
# Dice: 0.7272 | IoU: 0.5733 | Acc: 83.90%
#
# Epoch 72/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.32it/s, loss=0.982]
# Train Loss: 1.0363 | Val Loss: 0.7459
# Dice: 0.7126 | IoU: 0.5569 | Acc: 82.13%
#
# Epoch 73/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=1.42]
# Train Loss: 1.0160 | Val Loss: 0.6822
# Dice: 0.7315 | IoU: 0.5779 | Acc: 85.11%
#
# Epoch 74/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.32it/s, loss=1.55]
# Train Loss: 1.0369 | Val Loss: 0.7816
# Dice: 0.7006 | IoU: 0.5442 | Acc: 81.31%
#
# Epoch 75/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=1.85]
# Train Loss: 1.0928 | Val Loss: 0.6760
# Dice: 0.7315 | IoU: 0.5787 | Acc: 86.10%
#
# Epoch 76/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=0.727]
# Train Loss: 1.1182 | Val Loss: 0.9609
# Dice: 0.6452 | IoU: 0.4863 | Acc: 74.80%
#
# Epoch 77/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=1.33]
# Train Loss: 1.0421 | Val Loss: 0.6707
# Dice: 0.7384 | IoU: 0.5869 | Acc: 85.82%
# --> New best model saved! (Dice: 0.7384)
#
# Epoch 78/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=1.54]
# Train Loss: 1.0957 | Val Loss: 0.7785
# Dice: 0.7046 | IoU: 0.5496 | Acc: 82.04%
#
# Epoch 79/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=1.25]
# Train Loss: 1.0195 | Val Loss: 0.6967
# Dice: 0.7265 | IoU: 0.5718 | Acc: 86.15%
#
# Epoch 80/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.38it/s, loss=0.874]
# Train Loss: 1.0345 | Val Loss: 0.7238
# Dice: 0.7134 | IoU: 0.5556 | Acc: 85.91%
#
# Epoch 81/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.30it/s, loss=1.16]
# Train Loss: 1.0092 | Val Loss: 0.6436
# Dice: 0.7507 | IoU: 0.6018 | Acc: 86.66%
# --> New best model saved! (Dice: 0.7507)
#
# Epoch 82/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=1.08]
# Train Loss: 1.1399 | Val Loss: 0.7080
# Dice: 0.7291 | IoU: 0.5755 | Acc: 83.49%
#
# Epoch 83/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=0.794]
# Train Loss: 0.9515 | Val Loss: 0.7070
# Dice: 0.7293 | IoU: 0.5766 | Acc: 84.08%
#
# Epoch 84/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.32it/s, loss=0.991]
# Train Loss: 0.9533 | Val Loss: 0.6857
# Dice: 0.7406 | IoU: 0.5908 | Acc: 84.71%
#
# Epoch 85/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.32it/s, loss=0.992]
# Train Loss: 0.9477 | Val Loss: 0.6306
# Dice: 0.7604 | IoU: 0.6149 | Acc: 86.13%
# --> New best model saved! (Dice: 0.7604)
#
# Epoch 86/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.29it/s, loss=0.94]
# Train Loss: 0.9830 | Val Loss: 0.9350
# Dice: 0.6598 | IoU: 0.5024 | Acc: 77.25%
#
# Epoch 87/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=0.48]
# Train Loss: 0.9828 | Val Loss: 0.6386
# Dice: 0.7489 | IoU: 0.5994 | Acc: 86.78%
#
# Epoch 88/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=1.07]
# Train Loss: 0.9958 | Val Loss: 0.7160
# Dice: 0.7236 | IoU: 0.5707 | Acc: 83.82%
#
# Epoch 89/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.38it/s, loss=1.71]
# Train Loss: 0.9826 | Val Loss: 0.6601
# Dice: 0.7564 | IoU: 0.6095 | Acc: 88.20%
#
# Epoch 90/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=0.589]
# Train Loss: 1.0534 | Val Loss: 0.6593
# Dice: 0.7554 | IoU: 0.6082 | Acc: 87.27%
#
# Epoch 91/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=2.1]
# Train Loss: 0.9547 | Val Loss: 0.6632
# Dice: 0.7449 | IoU: 0.5948 | Acc: 86.61%
#
# Epoch 92/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=0.802]
# Train Loss: 0.9620 | Val Loss: 0.6677
# Dice: 0.7494 | IoU: 0.6007 | Acc: 86.60%
#
# Epoch 93/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.31it/s, loss=0.715]
# Train Loss: 0.9232 | Val Loss: 0.6045
# Dice: 0.7696 | IoU: 0.6264 | Acc: 87.72%
# --> New best model saved! (Dice: 0.7696)
#
# Epoch 94/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=0.855]
# Train Loss: 0.9933 | Val Loss: 0.6468
# Dice: 0.7530 | IoU: 0.6056 | Acc: 85.76%
#
# Epoch 95/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=0.668]
# Train Loss: 0.9331 | Val Loss: 0.6131
# Dice: 0.7683 | IoU: 0.6250 | Acc: 86.98%
#
# Epoch 96/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=0.994]
# Train Loss: 0.9456 | Val Loss: 0.5608
# Dice: 0.7845 | IoU: 0.6459 | Acc: 88.73%
# --> New best model saved! (Dice: 0.7845)
#
# Epoch 97/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=0.659]
# Train Loss: 0.8578 | Val Loss: 0.6421
# Dice: 0.7593 | IoU: 0.6136 | Acc: 86.02%
#
# Epoch 98/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=0.984]
# Train Loss: 0.9511 | Val Loss: 0.6099
# Dice: 0.7525 | IoU: 0.6043 | Acc: 87.70%
#
# Epoch 99/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.31it/s, loss=0.661]
# Train Loss: 1.0051 | Val Loss: 0.6882
# Dice: 0.7416 | IoU: 0.5914 | Acc: 85.25%
#
# Epoch 100/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=0.835]
# Train Loss: 0.9680 | Val Loss: 0.6036
# Dice: 0.7653 | IoU: 0.6215 | Acc: 86.85%
#
# Epoch 101/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.32it/s, loss=0.62]
# Train Loss: 1.0602 | Val Loss: 0.6982
# Dice: 0.7403 | IoU: 0.5921 | Acc: 84.64%
#
# Epoch 102/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.31it/s, loss=0.956]
# Train Loss: 0.9548 | Val Loss: 0.6488
# Dice: 0.7519 | IoU: 0.6045 | Acc: 85.44%
#
# Epoch 103/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=0.689]
# Train Loss: 0.9215 | Val Loss: 0.6949
# Dice: 0.7394 | IoU: 0.5890 | Acc: 84.76%
#
# Epoch 104/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=0.597]
# Train Loss: 0.7793 | Val Loss: 0.7800
# Dice: 0.7163 | IoU: 0.5626 | Acc: 81.65%
#
# Epoch 105/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=0.94]
# Train Loss: 1.0031 | Val Loss: 0.5735
# Dice: 0.7753 | IoU: 0.6348 | Acc: 88.01%
#
# Epoch 106/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=1.14]
# Train Loss: 0.9285 | Val Loss: 0.6439
# Dice: 0.7548 | IoU: 0.6082 | Acc: 86.92%
#
# Epoch 107/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.31it/s, loss=0.755]
# Train Loss: 0.9719 | Val Loss: 0.5616
# Dice: 0.7884 | IoU: 0.6519 | Acc: 88.10%
# --> New best model saved! (Dice: 0.7884)
#
# Epoch 108/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=0.561]
# Train Loss: 0.9846 | Val Loss: 0.6300
# Dice: 0.7601 | IoU: 0.6157 | Acc: 86.13%
#
# Epoch 109/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=1.28]
# Train Loss: 0.8860 | Val Loss: 0.6049
# Dice: 0.7734 | IoU: 0.6323 | Acc: 86.87%
#
# Epoch 110/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.32it/s, loss=0.847]
# Train Loss: 0.8907 | Val Loss: 0.5904
# Dice: 0.7732 | IoU: 0.6311 | Acc: 88.14%
#
# Epoch 111/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.32it/s, loss=0.445]
# Train Loss: 0.9537 | Val Loss: 0.6350
# Dice: 0.7561 | IoU: 0.6097 | Acc: 86.37%
#
# Epoch 112/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=0.677]
# Train Loss: 0.9473 | Val Loss: 0.7758
# Dice: 0.7137 | IoU: 0.5605 | Acc: 81.52%
#
# Epoch 113/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=0.87]
# Train Loss: 1.0096 | Val Loss: 0.5958
# Dice: 0.7719 | IoU: 0.6298 | Acc: 88.18%
#
# Epoch 114/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=0.651]
# Train Loss: 0.9434 | Val Loss: 0.6842
# Dice: 0.7430 | IoU: 0.5929 | Acc: 84.41%
#
# Epoch 115/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.30it/s, loss=1.25]
# Train Loss: 0.8393 | Val Loss: 0.7042
# Dice: 0.7312 | IoU: 0.5818 | Acc: 84.17%
#
# Epoch 116/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.38it/s, loss=0.985]
# Train Loss: 0.9644 | Val Loss: 0.6162
# Dice: 0.7760 | IoU: 0.6347 | Acc: 88.32%
#
# Epoch 117/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.31it/s, loss=1.08]
# Train Loss: 0.9473 | Val Loss: 0.7813
# Dice: 0.6950 | IoU: 0.5384 | Acc: 80.35%
#
# Epoch 118/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.37it/s, loss=1.21]
# Train Loss: 0.9574 | Val Loss: 0.5993
# Dice: 0.7690 | IoU: 0.6260 | Acc: 86.95%
#
# Epoch 119/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=1.44]
# Train Loss: 0.9653 | Val Loss: 0.6409
# Dice: 0.7528 | IoU: 0.6047 | Acc: 86.34%
#
# Epoch 120/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=0.332]
# Train Loss: 0.9027 | Val Loss: 0.7141
# Dice: 0.7360 | IoU: 0.5848 | Acc: 84.51%
#
# Epoch 121/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.30it/s, loss=0.578]
# Train Loss: 0.9896 | Val Loss: 0.6018
# Dice: 0.7688 | IoU: 0.6257 | Acc: 87.69%
#
# Epoch 122/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.29it/s, loss=0.656]
# Train Loss: 0.8883 | Val Loss: 0.6923
# Dice: 0.7456 | IoU: 0.5976 | Acc: 84.69%
#
# Epoch 123/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.39it/s, loss=0.769]
# Train Loss: 0.8639 | Val Loss: 0.8415
# Dice: 0.6871 | IoU: 0.5319 | Acc: 80.18%
#
# Epoch 124/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.37it/s, loss=0.695]
# Train Loss: 0.9394 | Val Loss: 0.7038
# Dice: 0.7339 | IoU: 0.5833 | Acc: 83.06%
#
# Epoch 125/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=1.89]
# Train Loss: 0.9606 | Val Loss: 0.5772
# Dice: 0.7845 | IoU: 0.6463 | Acc: 88.08%
#
# Epoch 126/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=0.715]
# Train Loss: 0.9669 | Val Loss: 0.6193
# Dice: 0.7675 | IoU: 0.6242 | Acc: 86.44%
#
# Epoch 127/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=0.766]
# Train Loss: 0.8637 | Val Loss: 0.5461
# Dice: 0.8023 | IoU: 0.6705 | Acc: 89.44%
# --> New best model saved! (Dice: 0.8023)
#
# Epoch 128/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.37it/s, loss=1.04]
# Train Loss: 0.9341 | Val Loss: 0.6777
# Dice: 0.7338 | IoU: 0.5804 | Acc: 86.06%
#
# Epoch 129/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=0.976]
# Train Loss: 0.9255 | Val Loss: 0.6239
# Dice: 0.7650 | IoU: 0.6206 | Acc: 87.30%
#
# Epoch 130/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=0.695]
# Train Loss: 0.9373 | Val Loss: 0.6783
# Dice: 0.7467 | IoU: 0.5991 | Acc: 85.14%
#
# Epoch 131/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=1.86]
# Train Loss: 0.8699 | Val Loss: 0.6669
# Dice: 0.7485 | IoU: 0.6004 | Acc: 86.08%
#
# Epoch 132/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=0.748]
# Train Loss: 0.9398 | Val Loss: 0.6141
# Dice: 0.7643 | IoU: 0.6210 | Acc: 85.83%
#
# Epoch 133/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.32it/s, loss=0.458]
# Train Loss: 0.8310 | Val Loss: 0.6336
# Dice: 0.7654 | IoU: 0.6219 | Acc: 86.76%
#
# Epoch 134/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.32it/s, loss=0.685]
# Train Loss: 0.9066 | Val Loss: 0.6481
# Dice: 0.7602 | IoU: 0.6139 | Acc: 87.91%
#
# Epoch 135/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=0.887]
# Train Loss: 0.8684 | Val Loss: 0.6746
# Dice: 0.7507 | IoU: 0.6027 | Acc: 85.04%
#
# Epoch 136/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=0.681]
# Train Loss: 0.9871 | Val Loss: 0.5693
# Dice: 0.7808 | IoU: 0.6417 | Acc: 87.74%
#
# Epoch 137/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=0.512]
# Train Loss: 0.8633 | Val Loss: 0.5881
# Dice: 0.7756 | IoU: 0.6356 | Acc: 86.82%
#
# Epoch 138/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.31it/s, loss=0.794]
# Train Loss: 0.8872 | Val Loss: 0.6396
# Dice: 0.7501 | IoU: 0.6040 | Acc: 84.98%
#
# Epoch 139/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.39it/s, loss=0.564]
# Train Loss: 0.9313 | Val Loss: 0.5617
# Dice: 0.7870 | IoU: 0.6505 | Acc: 87.87%
#
# Epoch 140/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.39it/s, loss=0.991]
# Train Loss: 0.8132 | Val Loss: 0.6693
# Dice: 0.7493 | IoU: 0.6022 | Acc: 85.13%
#
# Epoch 141/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=2.26]
# Train Loss: 0.9257 | Val Loss: 0.6739
# Dice: 0.7568 | IoU: 0.6110 | Acc: 85.79%
#
# Epoch 142/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.32it/s, loss=1.24]
# Train Loss: 0.8552 | Val Loss: 0.6152
# Dice: 0.7662 | IoU: 0.6231 | Acc: 86.67%
#
# Epoch 143/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=0.814]
# Train Loss: 0.9268 | Val Loss: 0.6385
# Dice: 0.7532 | IoU: 0.6075 | Acc: 85.02%
#
# Epoch 144/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.32it/s, loss=0.346]
# Train Loss: 0.8347 | Val Loss: 0.6693
# Dice: 0.7518 | IoU: 0.6057 | Acc: 85.26%
#
# Epoch 145/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.32it/s, loss=1.42]
# Train Loss: 0.8788 | Val Loss: 0.6510
# Dice: 0.7626 | IoU: 0.6192 | Acc: 85.43%
#
# Epoch 146/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=1.02]
# Train Loss: 0.9161 | Val Loss: 0.6050
# Dice: 0.7728 | IoU: 0.6313 | Acc: 86.45%
#
# Epoch 147/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.31it/s, loss=0.965]
# Train Loss: 0.8965 | Val Loss: 0.5629
# Dice: 0.7891 | IoU: 0.6525 | Acc: 88.97%
#
# Epoch 148/200
# Training: 100%|██████████| 41/41 [00:31<00:00,  1.32it/s, loss=0.819]
# Train Loss: 0.7854 | Val Loss: 0.5242
# Dice: 0.7997 | IoU: 0.6674 | Acc: 89.23%
#
# Epoch 149/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=0.85]
# Train Loss: 0.8997 | Val Loss: 0.5438
# Dice: 0.7929 | IoU: 0.6576 | Acc: 89.30%
#
# Epoch 150/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.32it/s, loss=0.463]
# Train Loss: 0.8025 | Val Loss: 0.5541
# Dice: 0.7940 | IoU: 0.6601 | Acc: 88.39%
#
# Epoch 151/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=0.301]
# Train Loss: 0.8326 | Val Loss: 0.5588
# Dice: 0.7904 | IoU: 0.6550 | Acc: 88.92%
#
# Epoch 152/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=0.818]
# Train Loss: 0.8146 | Val Loss: 0.5578
# Dice: 0.7964 | IoU: 0.6627 | Acc: 88.73%
#
# Epoch 153/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=0.873]
# Train Loss: 0.8294 | Val Loss: 0.6169
# Dice: 0.7675 | IoU: 0.6247 | Acc: 87.05%
#
# Epoch 154/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.37it/s, loss=1.22]
# Train Loss: 0.8782 | Val Loss: 0.5875
# Dice: 0.7763 | IoU: 0.6354 | Acc: 88.17%
#
# Epoch 155/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=0.544]
# Train Loss: 0.8847 | Val Loss: 0.6255
# Dice: 0.7700 | IoU: 0.6273 | Acc: 87.05%
#
# Epoch 156/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=0.748]
# Train Loss: 0.8732 | Val Loss: 0.7771
# Dice: 0.7221 | IoU: 0.5717 | Acc: 83.08%
#
# Epoch 157/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=0.546]
# Train Loss: 0.8765 | Val Loss: 0.5956
# Dice: 0.7801 | IoU: 0.6409 | Acc: 87.77%
#
# Epoch 158/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=0.445]
# Train Loss: 0.8397 | Val Loss: 0.6686
# Dice: 0.7501 | IoU: 0.6040 | Acc: 84.92%
#
# Epoch 159/200
# Training: 100%|██████████| 41/41 [00:28<00:00,  1.44it/s, loss=0.963]
# Train Loss: 0.9367 | Val Loss: 0.6553
# Dice: 0.7589 | IoU: 0.6148 | Acc: 84.66%
#
# Epoch 160/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=1.62]
# Train Loss: 0.9364 | Val Loss: 0.5851
# Dice: 0.7777 | IoU: 0.6376 | Acc: 87.14%
#
# Epoch 161/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=0.467]
# Train Loss: 0.8992 | Val Loss: 0.6810
# Dice: 0.7456 | IoU: 0.5981 | Acc: 83.16%
#
# Epoch 162/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.40it/s, loss=0.726]
# Train Loss: 0.7946 | Val Loss: 0.5515
# Dice: 0.7973 | IoU: 0.6648 | Acc: 88.93%
#
# Epoch 163/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=0.294]
# Train Loss: 0.8662 | Val Loss: 0.5385
# Dice: 0.7997 | IoU: 0.6676 | Acc: 89.20%
#
# Epoch 164/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=0.771]
# Train Loss: 0.8211 | Val Loss: 0.5468
# Dice: 0.7991 | IoU: 0.6665 | Acc: 88.73%
#
# Epoch 165/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.38it/s, loss=0.722]
# Train Loss: 0.8284 | Val Loss: 0.6092
# Dice: 0.7706 | IoU: 0.6286 | Acc: 86.67%
#
# Epoch 166/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.41it/s, loss=0.858]
# Train Loss: 0.8362 | Val Loss: 0.5601
# Dice: 0.7859 | IoU: 0.6489 | Acc: 87.54%
#
# Epoch 167/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=0.402]
# Train Loss: 0.9570 | Val Loss: 0.6006
# Dice: 0.7646 | IoU: 0.6202 | Acc: 88.03%
#
# Epoch 168/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.37it/s, loss=0.509]
# Train Loss: 0.8880 | Val Loss: 0.6116
# Dice: 0.7712 | IoU: 0.6290 | Acc: 87.41%
#
# Epoch 169/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=2.43]
# Train Loss: 0.8986 | Val Loss: 0.6450
# Dice: 0.7683 | IoU: 0.6268 | Acc: 86.28%
#
# Epoch 170/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.38it/s, loss=1.97]
# Train Loss: 0.9926 | Val Loss: 0.6112
# Dice: 0.7724 | IoU: 0.6309 | Acc: 86.98%
#
# Epoch 171/200
# Training: 100%|██████████| 41/41 [00:28<00:00,  1.42it/s, loss=0.939]
# Train Loss: 0.9297 | Val Loss: 0.5551
# Dice: 0.7880 | IoU: 0.6514 | Acc: 88.84%
#
# Epoch 172/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=0.79]
# Train Loss: 0.8861 | Val Loss: 0.5760
# Dice: 0.7806 | IoU: 0.6413 | Acc: 88.52%
#
# Epoch 173/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=1.85]
# Train Loss: 0.8969 | Val Loss: 0.5485
# Dice: 0.7884 | IoU: 0.6515 | Acc: 88.85%
#
# Epoch 174/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=0.631]
# Train Loss: 0.8643 | Val Loss: 0.5638
# Dice: 0.7910 | IoU: 0.6553 | Acc: 88.25%
#
# Epoch 175/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.39it/s, loss=1]
# Train Loss: 0.7496 | Val Loss: 0.5198
# Dice: 0.8071 | IoU: 0.6774 | Acc: 89.43%
# --> New best model saved! (Dice: 0.8071)
#
# Epoch 176/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.38it/s, loss=0.714]
# Train Loss: 0.8245 | Val Loss: 0.6087
# Dice: 0.7746 | IoU: 0.6340 | Acc: 86.83%
#
# Epoch 177/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.40it/s, loss=0.841]
# Train Loss: 0.7828 | Val Loss: 0.5753
# Dice: 0.7883 | IoU: 0.6524 | Acc: 88.25%
#
# Epoch 178/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.38it/s, loss=0.729]
# Train Loss: 0.7878 | Val Loss: 0.5817
# Dice: 0.7896 | IoU: 0.6538 | Acc: 87.39%
#
# Epoch 179/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.37it/s, loss=1.49]
# Train Loss: 0.8952 | Val Loss: 0.5270
# Dice: 0.8061 | IoU: 0.6765 | Acc: 89.16%
#
# Epoch 180/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.37it/s, loss=0.937]
# Train Loss: 0.9100 | Val Loss: 0.5934
# Dice: 0.7751 | IoU: 0.6348 | Acc: 86.76%
#
# Epoch 181/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.39it/s, loss=1.23]
# Train Loss: 0.8323 | Val Loss: 0.5597
# Dice: 0.7911 | IoU: 0.6558 | Acc: 87.69%
#
# Epoch 182/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=0.479]
# Train Loss: 0.8041 | Val Loss: 0.6670
# Dice: 0.7595 | IoU: 0.6149 | Acc: 85.47%
#
# Epoch 183/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.33it/s, loss=1.08]
# Train Loss: 0.8834 | Val Loss: 0.5880
# Dice: 0.7827 | IoU: 0.6448 | Acc: 87.36%
#
# Epoch 184/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.35it/s, loss=1.48]
# Train Loss: 0.8470 | Val Loss: 0.6630
# Dice: 0.7649 | IoU: 0.6219 | Acc: 85.11%
#
# Epoch 185/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.41it/s, loss=0.906]
# Train Loss: 0.8711 | Val Loss: 0.5661
# Dice: 0.7929 | IoU: 0.6576 | Acc: 89.39%
#
# Epoch 186/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.37it/s, loss=0.87]
# Train Loss: 0.8166 | Val Loss: 0.5315
# Dice: 0.8008 | IoU: 0.6689 | Acc: 89.21%
#
# Epoch 187/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=0.914]
# Train Loss: 0.7875 | Val Loss: 0.6594
# Dice: 0.7603 | IoU: 0.6167 | Acc: 85.32%
#
# Epoch 188/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=1.04]
# Train Loss: 0.7991 | Val Loss: 0.5758
# Dice: 0.7904 | IoU: 0.6544 | Acc: 89.02%
#
# Epoch 189/200
# Training: 100%|██████████| 41/41 [00:28<00:00,  1.43it/s, loss=0.878]
# Train Loss: 0.8489 | Val Loss: 0.5808
# Dice: 0.7889 | IoU: 0.6523 | Acc: 89.03%
#
# Epoch 190/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=0.6]
# Train Loss: 0.8665 | Val Loss: 0.5823
# Dice: 0.7831 | IoU: 0.6448 | Acc: 87.87%
#
# Epoch 191/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.39it/s, loss=0.504]
# Train Loss: 0.8955 | Val Loss: 0.5321
# Dice: 0.7989 | IoU: 0.6659 | Acc: 90.02%
#
# Epoch 192/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.38it/s, loss=0.504]
# Train Loss: 0.7787 | Val Loss: 0.5159
# Dice: 0.8130 | IoU: 0.6868 | Acc: 89.06%
# --> New best model saved! (Dice: 0.8130)
#
# Epoch 193/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.34it/s, loss=0.803]
# Train Loss: 0.8146 | Val Loss: 0.5167
# Dice: 0.8028 | IoU: 0.6716 | Acc: 90.28%
#
# Epoch 194/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.39it/s, loss=2.17]
# Train Loss: 0.8198 | Val Loss: 0.5220
# Dice: 0.8038 | IoU: 0.6733 | Acc: 89.87%
#
# Epoch 195/200
# Training: 100%|██████████| 41/41 [00:28<00:00,  1.42it/s, loss=0.557]
# Train Loss: 0.8233 | Val Loss: 0.5475
# Dice: 0.7974 | IoU: 0.6645 | Acc: 89.15%
#
# Epoch 196/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.38it/s, loss=0.874]
# Train Loss: 0.8173 | Val Loss: 0.4873
# Dice: 0.8163 | IoU: 0.6906 | Acc: 90.30%
# --> New best model saved! (Dice: 0.8163)
#
# Epoch 197/200
# Training: 100%|██████████| 41/41 [00:30<00:00,  1.36it/s, loss=1.91]
# Train Loss: 0.9201 | Val Loss: 0.5255
# Dice: 0.7972 | IoU: 0.6637 | Acc: 89.46%
#
# Epoch 198/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.41it/s, loss=0.536]
# Train Loss: 0.8981 | Val Loss: 0.5754
# Dice: 0.7774 | IoU: 0.6384 | Acc: 87.88%
#
# Epoch 199/200
# Training: 100%|██████████| 41/41 [00:29<00:00,  1.41it/s, loss=0.843]
# Train Loss: 0.7887 | Val Loss: 0.5209
# Dice: 0.8056 | IoU: 0.6752 | Acc: 89.94%
#
# Epoch 200/200
# Training: 100%|██████████| 41/41 [00:28<00:00,  1.42it/s, loss=0.764]
# Train Loss: 0.8402 | Val Loss: 0.5433
# Dice: 0.8024 | IoU: 0.6713 | Acc: 88.95%

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# --- CONFIGURATION ---
CSV_FILE = "/kaggle/working/training_log.csv"
OUTPUT_IMAGE = "metrics_plot.png"

def plot_training_metrics(csv_file, output_file):
    # 1. Load Data
    try:
        df = pd.read_csv(csv_file)
    except FileNotFoundError:
        print(f"Error: Could not find {csv_file}. Make sure you have run the training script first.")
        return

    # 2. Set "Aesthetic" Style (Seaborn)
    sns.set_theme(style="whitegrid", context="paper", font_scale=1.2)
    
    # Create a figure with a 2x3 grid
    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
    fig.suptitle('Training & Validation Metrics', fontsize=20, fontweight='bold', y=0.98)

    # --- PLOT 1: LOSS (Train vs Val) ---
    sns.lineplot(ax=axes[0, 0], data=df, x='epoch', y='train_loss', label='Train Loss', 
                 linewidth=2.5, color='#E74C3C', marker='o')
    sns.lineplot(ax=axes[0, 0], data=df, x='epoch', y='val_loss', label='Val Loss', 
                 linewidth=2.5, color='#2E86C1', marker='o')
    axes[0, 0].set_title('Loss Curves', fontweight='bold')
    axes[0, 0].set_ylabel('Loss')
    axes[0, 0].legend()

    # --- PLOT 2: DICE & IoU (The most important segmentation metrics) ---
    sns.lineplot(ax=axes[0, 1], data=df, x='epoch', y='dice', label='Dice Score', 
                 linewidth=2.5, color='#27AE60', marker='s')
    sns.lineplot(ax=axes[0, 1], data=df, x='epoch', y='iou', label='IoU Score', 
                 linewidth=2.5, color='#F39C12', marker='s')
    axes[0, 1].set_title('Segmentation Performance (Dice & IoU)', fontweight='bold')
    axes[0, 1].set_ylabel('Score (0-1)')
    axes[0, 1].legend()

    # --- PLOT 3: ACCURACY ---
    sns.lineplot(ax=axes[0, 2], data=df, x='epoch', y='accuracy', 
                 linewidth=2.5, color='#8E44AD', marker='D')
    axes[0, 2].set_title('Pixel Accuracy (%)', fontweight='bold')
    axes[0, 2].set_ylabel('Accuracy (%)')

    # --- PLOT 4: PRECISION vs RECALL ---
    sns.lineplot(ax=axes[1, 0], data=df, x='epoch', y='precision', label='Precision', 
                 linewidth=2.5, color='#16A085', marker='^')
    sns.lineplot(ax=axes[1, 0], data=df, x='epoch', y='recall', label='Recall', 
                 linewidth=2.5, color='#C0392B', marker='v')
    axes[1, 0].set_title('Precision vs Recall', fontweight='bold')
    axes[1, 0].set_ylabel('Score (0-1)')
    axes[1, 0].legend()

    # --- PLOT 5: DICE vs LOSS (Correlation check) ---
    # Helps see if Loss going down actually improves Dice
    ax2 = axes[1, 1].twinx()
    sns.lineplot(ax=axes[1, 1], data=df, x='epoch', y='val_loss', color='#2E86C1', 
                 label='Val Loss', legend=False, linestyle='--')
    sns.lineplot(ax=ax2, data=df, x='epoch', y='dice', color='#27AE60', 
                 label='Dice', legend=False, linewidth=2.5)
    
    axes[1, 1].set_title('Correlation: Val Loss (Blue) vs Dice (Green)', fontweight='bold')
    axes[1, 1].set_ylabel('Val Loss')
    ax2.set_ylabel('Dice Score')
    
    # --- PLOT 6: DATA TABLE (Summary) ---
    axes[1, 2].axis('off')
    # Create a concise table of the best epoch
    best_epoch_idx = df['dice'].idxmax()
    best_row = df.iloc[best_epoch_idx]
    
    table_text = [
        ["Metric", "Best Value"],
        ["Best Epoch", int(best_row['epoch'])],
        ["Dice Score", f"{best_row['dice']:.4f}"],
        ["IoU Score", f"{best_row['iou']:.4f}"],
        ["Precision", f"{best_row['precision']:.4f}"],
        ["Recall", f"{best_row['recall']:.4f}"],
        ["Val Loss", f"{best_row['val_loss']:.4f}"],
    ]
    
    table = axes[1, 2].table(cellText=table_text, loc='center', cellLoc='center', 
                             colWidths=[0.4, 0.4])
    table.auto_set_font_size(False)
    table.set_fontsize(12)
    table.scale(1, 2) # Make rows taller
    axes[1, 2].set_title(f"Best Model Summary (Epoch {int(best_row['epoch'])})", fontweight='bold')

    # Final Layout Adjustments
    plt.tight_layout()
    plt.subplots_adjust(top=0.92) # Make space for main title
    
    # Save
    plt.savefig(output_file, dpi=300, bbox_inches='tight')
    print(f"✅ Plots saved successfully to {output_file}")
    plt.show()

if __name__ == "__main__":
    plot_training_metrics(CSV_FILE, OUTPUT_IMAGE)
# Out:
# ✅ Plots saved successfully to metrics_plot.png

# %%
import torch
import numpy as np
import cv2
import matplotlib.pyplot as plt
import albumentations as A
from albumentations.pytorch import ToTensorV2
from tqdm import tqdm
import math

# --- IMPORT YOUR MODEL ---
# from model import ResAttUNet  # <--- Make sure this is imported!

# --- CONFIG ---
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
CHECKPOINT_PATH = "best_checkpoint.pth.tar"
IMAGE_PATH = "/kaggle/input/inria-aerial-image-labeling-dataset/AerialImageDataset/test/images/bellingham1.tif"
PATCH_SIZE = 512  # Must match your training IMAGE_HEIGHT/WIDTH

def predict_sliding_window(model, image_path, patch_size=512):
    # 1. Read Image
    original_img = cv2.imread(image_path)
    if original_img is None: raise ValueError(f"Image not found: {image_path}")
    original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)
    
    h, w, _ = original_img.shape
    
    # 2. Pad image to be divisible by patch_size (simplifies logic)
    pad_h = (patch_size - h % patch_size) % patch_size
    pad_w = (patch_size - w % patch_size) % patch_size
    
    padded_img = np.pad(original_img, ((0, pad_h), (0, pad_w), (0, 0)), mode='constant', constant_values=0)
    new_h, new_w, _ = padded_img.shape
    
    # 3. Prepare Canvas for the Mask
    full_mask = np.zeros((new_h, new_w), dtype=np.float32)
    
    # Transform (Normalize only, NO RESIZING)
    transform = A.Compose([
        A.Normalize(mean=[0.0, 0.0, 0.0], std=[1.0, 1.0, 1.0], max_pixel_value=255.0),
        ToTensorV2(),
    ])

    print(f"Processing image of size {h}x{w} in {patch_size}x{patch_size} patches...")

    # 4. Slide the window
    model.eval()
    with torch.no_grad():
        for y in range(0, new_h, patch_size):
            for x in range(0, new_w, patch_size):
                # Extract Patch
                patch = padded_img[y:y+patch_size, x:x+patch_size]
                
                # Preprocess Patch
                aug = transform(image=patch)
                patch_tensor = aug["image"].unsqueeze(0).to(DEVICE)
                
                # Inference
                outputs = model(patch_tensor)
                logits = outputs[0] # Assuming model returns [final, mid, coarse]
                probs = torch.sigmoid(logits)
                
                # Move to CPU and Fill Canvas
                pred_patch = probs.squeeze().cpu().numpy()
                full_mask[y:y+patch_size, x:x+patch_size] = pred_patch

    # 5. Crop back to original size
    final_mask = full_mask[:h, :w]
    
    # Thresholding
    binary_mask = (final_mask > 0.5).astype(np.uint8)
    
    return original_img, binary_mask

# --- VISUALIZATION (Unchanged) ---
def visualize_result(image, mask):
    # Resize for display purposes if the image is too huge
    disp_h, disp_w = 1024, 1024 
    img_show = cv2.resize(image, (disp_w, disp_h))
    mask_show = cv2.resize(mask, (disp_w, disp_h), interpolation=cv2.INTER_NEAREST)
    
    mask_colored = np.zeros_like(img_show)
    mask_colored[:, :, 0] = 255 # Red overlay
    
    overlay = img_show.copy()
    mask_indices = mask_show > 0
    overlay[mask_indices] = cv2.addWeighted(img_show[mask_indices], 0.7, mask_colored[mask_indices], 0.3, 0)

    fig, ax = plt.subplots(1, 2, figsize=(12, 6))
    ax[0].imshow(img_show)
    ax[0].set_title("Original (Resized for Display)")
    ax[0].axis("off")
    
    ax[1].imshow(overlay)
    ax[1].set_title("Prediction Overlay")
    ax[1].axis("off")
    plt.tight_layout()
    plt.show()

# --- MAIN ---
if __name__ == "__main__":
    # Ensure you import ResAttUNet correctly here or define it
    # from model import ResAttUNet 
    
    # Mocking the load function for clarity
    model = ResAttUNet(in_channels=3, out_channels=1).to(DEVICE)
    checkpoint = torch.load(CHECKPOINT_PATH, map_location=DEVICE)
    model.load_state_dict(checkpoint["state_dict"])
    
    img, pred_mask = predict_sliding_window(model, IMAGE_PATH, PATCH_SIZE)
    visualize_result(img, pred_mask)
# Out:
# Processing image of size 5000x5000 in 512x512 patches...
